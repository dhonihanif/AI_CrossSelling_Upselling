# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, OrdinalEncoder
from sklearn.pipeline import Pipeline  
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve

# %%
df = pd.read_csv(r"C:\Users\DHONI HANIF\OneDrive\Documents\AI Sales Cross Selling and UpSelling\data\dataset\HC and Training Series.csv")
df.head()
# Out:
#    Unnamed: 0 company_ID          company_name              company_pic  \
# 0           0      P0001   Tribakti Inspektama         Lasmanto Pratiwi
# 1           1      P0002  Bank Bukopin Syariah     Puti Gina Napitupulu
# 2           2      P0003  Bank Bukopin Syariah  Karna Purwanti, S.I.Kom
# 3           3      P0004      Kementrian Agama            Tania Yolanda
# 4           4      P0005                 M3kom        Zaenab Anggriawan
#
#                                      company_address        company_phone  \
# 0  Jalan Cihampelas No. 282\nPontianak, Kalimanta...   +62 (183) 655 1415
# 1    Jalan Tubagus Ismail No. 02\nSukabumi, BB 74318       (097) 773 7113
# 2    Gg. Pelajar Pejuang No. 660\nJambi, Jambi 60449  +62 (0801) 007-5669
# 3               Jl. Cihampelas No. 8\nTual, ST 59647    +62-0247-253-2150
# 4    Gang Moch. Ramdan No. 083\nPayakumbuh, SS 13214       (025) 406 2520
#
#                   company_email  \
# 0  muhammadnasyidah@example.org
# 1     januarkamaria@example.net
# 2         rprasetyo@example.net
# 3    iswahyudiraisa@example.net
# 4         mulyono67@example.com
#
#                                        company_field transaction_date  \
# 0                    Aktivitas Keuangan dan Asuransi       2020-01-01
# 1  Aktivitas Badan Internasional Dan Badan Ekstra...       2020-01-02
# 2  Pengadaan Listrik, Gas, Uap/Air Panas Dan Udar...       2020-01-03
# 3                                         Konstruksi       2020-01-04
# 4                           Informasi Dan Komunikasi       2020-01-05
#
#    level_training_process  ... interest_in_discount_program  training_ID  \
# 0                       5  ...                            5        B0001
# 1                       5  ...                            5        B0002
# 2                       5  ...                            5        B0003
# 3                       5  ...                            5        B0004
# 4                       5  ...                            5        B0005
#
#   trainer_name  training_total_meetings  training_price discount_training  \
# 0         Ibun                       17       6000000.0                50
# 1         Reza                       17       5500000.0                50
# 2         Ibun                       14       6000000.0                50
# 3         Reza                       17       6000000.0                50
# 4        Haris                       17       6000000.0                50
#
#             training_type                                      training_name  \
# 0  HC and Training Series  People (HR) Analytics for HR & Non HR Professi...
# 1  HC and Training Series  People (HR) Analytics for HR & Non HR Professi...
# 2  HC and Training Series  People (HR) Analytics for HR & Non HR Professi...
# 3  HC and Training Series  People (HR) Analytics for HR & Non HR Professi...
# 4  HC and Training Series  People (HR) Analytics for HR & Non HR Professi...
#
#                               cross_selling  \
# 0  Digital Mindset & Capability Debelopment
# 1  Digital Mindset & Capability Debelopment
# 2  Digital Mindset & Capability Debelopment
# 3  Digital Mindset & Capability Debelopment
# 4  Digital Mindset & Capability Debelopment
#
#                                            upselling
# 0  People (HR) Analytics for HR & Non HR Professi...
# 1  People (HR) Analytics for HR & Non HR Professi...
# 2  People (HR) Analytics for HR & Non HR Professi...
# 3  People (HR) Analytics for HR & Non HR Professi...
# 4  People (HR) Analytics for HR & Non HR Professi...
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 33 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Unnamed: 0                                   5000 non-null   int64
#  1   company_ID                                   5000 non-null   object
#  2   company_name                                 5000 non-null   object
#  3   company_pic                                  5000 non-null   object
#  4   company_address                              5000 non-null   object
#  5   company_phone                                5000 non-null   object
#  6   company_email                                5000 non-null   object
#  7   company_field                                5000 non-null   object
#  8   transaction_date                             5000 non-null   object
#  9   level_training_process                       5000 non-null   int64
#  10  purchasing_time_patterns                     5000 non-null   object
#  11  number_of_participants                       5000 non-null   int64
#  12  group                                        5000 non-null   object
#  13  total_payment                                5000 non-null   float64
#  14  satisfaction                                 5000 non-null   int64
#  15  communication_channel                        5000 non-null   object
#  16  complaints                                   5000 non-null   object
#  17  communication_quality                        5000 non-null   object
#  18  possibility_of_purchasing_the_same_training  5000 non-null   int64
#  19  frequency_engagement                         5000 non-null   int64
#  20  brand_sustainability                         5000 non-null   int64
#  21  rating_training                              5000 non-null   int64
#  22  tren_mode_factor                             5000 non-null   object
#  23  interest_in_discount_program                 5000 non-null   int64
#  24  training_ID                                  5000 non-null   object
#  25  trainer_name                                 5000 non-null   object
#  26  training_total_meetings                      5000 non-null   int64
#  27  training_price                               5000 non-null   float64
#  28  discount_training                            5000 non-null   int64
#  29  training_type                                5000 non-null   object
#  30  training_name                                5000 non-null   object
#  31  cross_selling                                5000 non-null   object
#  32  upselling                                    5000 non-null   object
# dtypes: float64(2), int64(11), object(20)
# memory usage: 1.3+ MB

# %%
for i in df.columns:
    if df[i].dtype == "object":
        df[i] = df[i].astype("category")

# %%
# Preprocessing untuk fitur kategori
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ordinal', OrdinalEncoder())
])

# Preprocessing untuk fitur numerik
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', MinMaxScaler())
])

numeric_features = ["level_training_process", "total_payment", "satisfaction",
                    "frequency_engagement", "brand_sustainability", "interest_in_discount_program",
                    "training_price", "discount_training"]

categorical_features = ["group", "complaints"]

drop_features = ["Unnamed: 0", "company_ID", "company_name", "company_pic", "company_address", "company_phone", "company_email", "company_field",
                 "transaction_date", "purchasing_time_patterns", "number_of_participants", "rating_training",
                 "training_ID", "training_total_meetings", "training_type","possibility_of_purchasing_the_same_training", "training_name",
                 "trainer_name", "communication_channel", "tren_mode_factor", "cross_selling", "communication_quality"]

# Gabungkan transformer dengan ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features),
        ('drop', 'drop', drop_features)
    ],
    remainder="passthrough"
    )

# %%
X = df.drop("upselling", axis=1)
y = df["upselling"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

pkl = joblib.load(r"C:\Users\DHONI HANIF\OneDrive\Documents\AI Sales Cross Selling and UpSelling\modelling\classification\upselling\model_save\model3.pkl")
model = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("models", pkl)
])
model.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000107 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 184
# [LightGBM] [Info] Number of data points in the train set: 4000, number of used features: 10
# [LightGBM] [Info] Start training from score -2.067513
# [LightGBM] [Info] Start training from score -2.077444
# [LightGBM] [Info] Start training from score -2.093540
# [LightGBM] [Info] Start training from score -2.095571
# [LightGBM] [Info] Start training from score -2.105786
# [LightGBM] [Info] Start training from score -2.046007
# [LightGBM] [Info] Start training from score -2.051826
# [LightGBM] [Info] Start training from score -2.099644
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['level_training_process',
#                                                    'total_payment',
#                                                    'satisfaction',
#                                                    'frequency_engagement',
#                                                    'brand_sustainability',
#                                                    'interest_in_discount_program',
#                                                    'training_price',
#                                                    'discount_training']),
#                                                  ('cat',
#                                                   Pip...
#                                                    'purchasing_time_patterns',
#                                                    'number_of_participants',
#                                                    'rating_training',
#                                                    'training_ID',
#                                                    'training_total_meetings',
#                                                    'training_type',
#                                                    'possibility_of_purchasing_the_same_training',
#                                                    'training_name',
#                                                    'trainer_name',
#                                                    'communication_channel',
#                                                    'tren_mode_factor',
#                                                    'cross_selling',
#                                                    'communication_quality'])])),
#                 ('models',
#                  LGBMClassifier(max_depth=3, n_estimators=50, num_leaves=15))])

# %%
y_pred = model.predict(X_test)
fig, ax = plt.subplots(1, 2, figsize=(10, 5), layout="constrained")
sns.heatmap(confusion_matrix(y_train, model.predict(X_train)), annot=True, fmt="d", linecolor="white", linewidths=0.2, cmap="winter", ax=ax[0])
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt="d", linecolor="white", linewidths=0.2, cmap="winter", ax=ax[1])

ax[0].set_title("Training")
ax[1].set_title("Testing")
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#                                                                                 precision    recall  f1-score   support
#
#                                     Build A Great and Strong Corporate Culture       0.87      0.90      0.89       116
#                                   Business Acumen: Think, Sense & Act like CEO       0.87      0.87      0.87       133
#                                       Digital Mindset & Capability Debelopment       0.89      0.89      0.89       133
# How to Conduct Social Campaign (for the Benefit of HR and Corporat Reputation)       0.88      0.87      0.87       115
#                             People (HR) Analytics for HR & Non HR Professional       0.89      0.90      0.89       137
#                                Planning and Organizing for Stellar Performance       0.89      0.86      0.88       111
#                       Professional Capability Development Towards Industry 4.0       0.90      0.91      0.90       120
#                                 Transformasi Budaya & Manajemen Agen Perubahan       0.89      0.89      0.89       135
#
#                                                                       accuracy                           0.89      1000
#                                                                      macro avg       0.89      0.89      0.89      1000
#                                                                   weighted avg       0.89      0.89      0.89      1000

# %%
a = model.predict_proba(X_test.iloc[-1:, :])
b = ["Build A Great and Strong Corporate Culture", "Business Acumen: Think, Sense & Act like CEO", "Digital Mindset & Capability Debelopment"
     "How to Conduct Social Campaign (for the Benefit of HR and Corporat Reputation)", "People (HR) Analytics for HR & Non HR Professional",
     "Planning and Organizing for Stellar Performance", "Professional Capability Development Towards Industry 4.0", 
     "Transformasi Budaya & Manajemen Agen Perubahan"]

for i, j in zip(b, a.ravel()):
    print(i, f"{j*100:.2f}%")
# Out:
# Build A Great and Strong Corporate Culture 90.02%
# Business Acumen: Think, Sense & Act like CEO 0.06%
# Digital Mindset & Capability DebelopmentHow to Conduct Social Campaign (for the Benefit of HR and Corporat Reputation) 0.06%
# People (HR) Analytics for HR & Non HR Professional 0.10%
# Planning and Organizing for Stellar Performance 0.06%
# Professional Capability Development Towards Industry 4.0 9.46%
# Transformasi Budaya & Manajemen Agen Perubahan 0.15%

# %%
model.predict(X_test.iloc[-1:, :])
# Out:
# array(['Build A Great and Strong Corporate Culture'], dtype=object)

# %%
y_test.iloc[-1]
# Out:
# 'Build A Great and Strong Corporate Culture'
