# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, OrdinalEncoder
from sklearn.pipeline import Pipeline  
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve

# %%
df = pd.read_csv(r"C:\Users\DHONI HANIF\OneDrive\Documents\AI Sales Cross Selling and UpSelling\data\dataset\Training Series.csv")
df.head()
# Out:
#    Unnamed: 0 company_ID          company_name              company_pic  \
# 0           0      P0001   Tribakti Inspektama         Lasmanto Pratiwi
# 1           1      P0002  Bank Bukopin Syariah     Puti Gina Napitupulu
# 2           2      P0003  Bank Bukopin Syariah  Karna Purwanti, S.I.Kom
# 3           3      P0004      Kementrian Agama            Tania Yolanda
# 4           4      P0005                 M3kom        Zaenab Anggriawan
#
#                                      company_address        company_phone  \
# 0  Jalan Cihampelas No. 282\nPontianak, Kalimanta...   +62 (183) 655 1415
# 1    Jalan Tubagus Ismail No. 02\nSukabumi, BB 74318       (097) 773 7113
# 2    Gg. Pelajar Pejuang No. 660\nJambi, Jambi 60449  +62 (0801) 007-5669
# 3               Jl. Cihampelas No. 8\nTual, ST 59647    +62-0247-253-2150
# 4    Gang Moch. Ramdan No. 083\nPayakumbuh, SS 13214       (025) 406 2520
#
#                   company_email  \
# 0  muhammadnasyidah@example.org
# 1     januarkamaria@example.net
# 2         rprasetyo@example.net
# 3    iswahyudiraisa@example.net
# 4         mulyono67@example.com
#
#                                        company_field transaction_date  \
# 0                    Aktivitas Keuangan dan Asuransi       2020-01-01
# 1  Aktivitas Badan Internasional Dan Badan Ekstra...       2020-01-02
# 2  Pengadaan Listrik, Gas, Uap/Air Panas Dan Udar...       2020-01-03
# 3                                         Konstruksi       2020-01-04
# 4                           Informasi Dan Komunikasi       2020-01-05
#
#    level_training_process  ... training_total_meetings  training_price  \
# 0                       5  ...                      17       6000000.0
# 1                       5  ...                      17       6000000.0
# 2                       5  ...                      14       6000000.0
# 3                       5  ...                      17       6000000.0
# 4                       5  ...                      17       6000000.0
#
#   discount_training  satisfaction_level  training_session  \
# 0                50                   5                17
# 1                50                   5                17
# 2                50                   5                17
# 3                50                   5                17
# 4                50                   5                17
#
#   number_of_participant   training_field                     training_name  \
# 0                    19  Training Series  Comprehensive Train The Trainers
# 1                    18  Training Series  Comprehensive Train The Trainers
# 2                    18  Training Series  Comprehensive Train The Trainers
# 3                    18  Training Series  Comprehensive Train The Trainers
# 4                    20  Training Series  Comprehensive Train The Trainers
#
#                                        cross_selling  \
# 0   Menyusun Kurikulum Pelatihan Berbasis Kompetensi
# 1  Train The Trainer For Outbound (Indoor-outdoor...
# 2  Train The Trainer For Outbound (Indoor-outdoor...
# 3  Train The Trainer For Outbound (Indoor-outdoor...
# 4  Train The Trainer For Outbound (Indoor-outdoor...
#
#                                            upselling
# 0                   Comprehensive Train The Trainers
# 1                   Comprehensive Train The Trainers
# 2  Train The Trainer For Outbound (Indoor-outdoor...
# 3                   Comprehensive Train The Trainers
# 4                   Comprehensive Train The Trainers
#
# [5 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 36 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Unnamed: 0                                   5000 non-null   int64
#  1   company_ID                                   5000 non-null   object
#  2   company_name                                 5000 non-null   object
#  3   company_pic                                  5000 non-null   object
#  4   company_address                              5000 non-null   object
#  5   company_phone                                5000 non-null   object
#  6   company_email                                5000 non-null   object
#  7   company_field                                5000 non-null   object
#  8   transaction_date                             5000 non-null   object
#  9   level_training_process                       5000 non-null   int64
#  10  purchasing_time_patterns                     5000 non-null   object
#  11  number_of_participants                       5000 non-null   int64
#  12  group                                        5000 non-null   object
#  13  total_payment                                5000 non-null   float64
#  14  satisfaction                                 5000 non-null   int64
#  15  communication_channel                        5000 non-null   object
#  16  complaints                                   5000 non-null   object
#  17  communication_quality                        5000 non-null   object
#  18  possibility_of_purchasing_the_same_training  5000 non-null   int64
#  19  frequency_engagement                         5000 non-null   int64
#  20  brand_sustainability                         5000 non-null   int64
#  21  rating_training                              5000 non-null   int64
#  22  tren_mode_factor                             5000 non-null   object
#  23  interest_in_discount_program                 5000 non-null   int64
#  24  training_ID                                  5000 non-null   object
#  25  trainer_name                                 5000 non-null   object
#  26  training_total_meetings                      5000 non-null   int64
#  27  training_price                               5000 non-null   float64
#  28  discount_training                            5000 non-null   int64
#  29  satisfaction_level                           5000 non-null   int64
#  30  training_session                             5000 non-null   int64
#  31  number_of_participant                        5000 non-null   int64
#  32  training_field                               5000 non-null   object
#  33  training_name                                5000 non-null   object
#  34  cross_selling                                5000 non-null   object
#  35  upselling                                    5000 non-null   object
# dtypes: float64(2), int64(14), object(20)
# memory usage: 1.4+ MB

# %%
for i in df.columns:
    if df[i].dtype == "object":
        df[i] = df[i].astype("category")

# %%
# Preprocessing untuk fitur kategori
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ordinal', OrdinalEncoder())
])

# Preprocessing untuk fitur numerik
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', MinMaxScaler())
])

numeric_features = ["level_training_process", "total_payment", "satisfaction_level",
                    "frequency_engagement", "brand_sustainability", "interest_in_discount_program",
                    "training_session", "discount_training", "number_of_participant"]

categorical_features = ["group"]

df.info()
drop_features = ["Unnamed: 0", "company_ID", "company_name", "company_pic", "company_address", "company_phone", "company_email", "company_field",
                 "transaction_date", "purchasing_time_patterns", "rating_training", "complaints",
                 "training_ID", "training_field","possibility_of_purchasing_the_same_training", "training_name",
                 "trainer_name", "communication_channel", "tren_mode_factor", "cross_selling", "communication_quality"]

# Gabungkan transformer dengan ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features),
        ('drop', 'drop', drop_features)
    ],
    remainder="passthrough"
    )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 36 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Unnamed: 0                                   5000 non-null   int64
#  1   company_ID                                   5000 non-null   category
#  2   company_name                                 5000 non-null   category
#  3   company_pic                                  5000 non-null   category
#  4   company_address                              5000 non-null   category
#  5   company_phone                                5000 non-null   category
#  6   company_email                                5000 non-null   category
#  7   company_field                                5000 non-null   category
#  8   transaction_date                             5000 non-null   category
#  9   level_training_process                       5000 non-null   int64
#  10  purchasing_time_patterns                     5000 non-null   category
#  11  number_of_participants                       5000 non-null   int64
#  12  group                                        5000 non-null   category
#  13  total_payment                                5000 non-null   float64
#  14  satisfaction                                 5000 non-null   int64
#  15  communication_channel                        5000 non-null   category
#  16  complaints                                   5000 non-null   category
#  17  communication_quality                        5000 non-null   category
#  18  possibility_of_purchasing_the_same_training  5000 non-null   int64
#  19  frequency_engagement                         5000 non-null   int64
#  20  brand_sustainability                         5000 non-null   int64
#  21  rating_training                              5000 non-null   int64
#  22  tren_mode_factor                             5000 non-null   category
#  23  interest_in_discount_program                 5000 non-null   int64
#  24  training_ID                                  5000 non-null   category
#  25  trainer_name                                 5000 non-null   category
#  26  training_total_meetings                      5000 non-null   int64
#  27  training_price                               5000 non-null   float64
#  28  discount_training                            5000 non-null   int64
#  29  satisfaction_level                           5000 non-null   int64
#  30  training_session                             5000 non-null   int64
#  31  number_of_participant                        5000 non-null   int64
#  32  training_field                               5000 non-null   category
#  33  training_name                                5000 non-null   category
#  34  cross_selling                                5000 non-null   category
#  35  upselling                                    5000 non-null   category
# dtypes: category(20), float64(2), int64(14)
# memory usage: 2.1 MB

# %%
X = df.drop("upselling", axis=1)
y = df["upselling"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

pkl = joblib.load(r"C:\Users\DHONI HANIF\OneDrive\Documents\AI Sales Cross Selling and UpSelling\modelling\classification\upselling\model_save\model7.pkl")
model = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("models", pkl)
])
model.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000438 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 211
# [LightGBM] [Info] Number of data points in the train set: 4000, number of used features: 14
# [LightGBM] [Info] Start training from score -1.593319
# [LightGBM] [Info] Start training from score -1.601966
# [LightGBM] [Info] Start training from score -1.581093
# [LightGBM] [Info] Start training from score -1.639897
# [LightGBM] [Info] Start training from score -1.632195
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['level_training_process',
#                                                    'total_payment',
#                                                    'satisfaction_level',
#                                                    'frequency_engagement',
#                                                    'brand_sustainability',
#                                                    'interest_in_discount_program',
#                                                    'training_session',
#                                                    'discount_training',
#                                                    'num...
#                                                    'transaction_date',
#                                                    'purchasing_time_patterns',
#                                                    'rating_training',
#                                                    'complaints', 'training_ID',
#                                                    'training_field',
#                                                    'possibility_of_purchasing_the_same_training',
#                                                    'training_name',
#                                                    'trainer_name',
#                                                    'communication_channel',
#                                                    'tren_mode_factor',
#                                                    'cross_selling',
#                                                    'communication_quality'])])),
#                 ('models',
#                  LGBMClassifier(learning_rate=0.01, max_depth=3,
#                                 n_estimators=50, num_leaves=15))])

# %%
y_pred = model.predict(X_test)
fig, ax = plt.subplots(1, 2, figsize=(10, 5), layout="constrained")
sns.heatmap(confusion_matrix(y_train, model.predict(X_train)), annot=True, fmt="d", linecolor="white", linewidths=0.2, cmap="winter", ax=ax[0])
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt="d", linecolor="white", linewidths=0.2, cmap="winter", ax=ax[1])

ax[0].set_title("Training")
ax[1].set_title("Testing")
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#                                                                                  precision    recall  f1-score   support
#
#                                                Comprehensive Train The Trainers       0.92      0.89      0.90       203
#                           Drill for Trainers: Mastering 10 Core Trainer's Tools       0.86      0.85      0.85       202
# How to Conduct TNA, Creating Training Material & Measuring Training Effectivity       0.90      0.84      0.87       188
#                                Menyusun Kurikulum Pelatihan Berbasis Kompetensi       0.81      0.88      0.84       204
#                        Train The Trainer For Outbound (Indoor-outdoor) Activity       0.89      0.92      0.91       203
#
#                                                                        accuracy                           0.87      1000
#                                                                       macro avg       0.88      0.87      0.87      1000
#                                                                    weighted avg       0.88      0.87      0.87      1000

# %%
a = model.predict_proba(X_test.iloc[:1, :])
b = ["Comprehensive Train The Trainers", "Drill for Trainers: Mastering 10 Core Trainer's Tools", 
     "How to Conduct TNA, Creating Training Material & Measuring Training Effectivity", "Menyusun Kurikulum Pelatihan Berbasis Kompetensi",
     "Train The Trainer For Outbound (Indoor-outdoor) Activity",
     ]

for i, j in zip(b, a.ravel()):
    print(i, f"{j*100:.2f}%")
# Out:
# Comprehensive Train The Trainers 51.43%
# Drill for Trainers: Mastering 10 Core Trainer's Tools 11.48%
# How to Conduct TNA, Creating Training Material & Measuring Training Effectivity 11.70%
# Menyusun Kurikulum Pelatihan Berbasis Kompetensi 11.09%
# Train The Trainer For Outbound (Indoor-outdoor) Activity 14.31%

# %%
model.predict(X_test.iloc[:1, :])
# Out:
# array(['Comprehensive Train The Trainers'], dtype=object)

# %%
y_test.iloc[0]
# Out:
# 'Comprehensive Train The Trainers'

# %%
X_test.iloc[:1, :]
# Out:
#       Unnamed: 0 company_ID                 company_name     company_pic  \
# 1501        1501      P1502  UD Napitupulu (Persero) Tbk  Kadir Sitompul
#
#                                         company_address        company_phone  \
# 1501  Gg. Otto Iskandardinata No. 14\nSalatiga, DKI ...  +62 (0993) 413-3583
#
#                     company_email  \
# 1501  purwantitugiman@example.org
#
#                                          company_field transaction_date  \
# 1501  Aktivitas Kesehatan Manusia Dan Aktivitas Sosial       2024-02-10
#
#       level_training_process  ... trainer_name  training_total_meetings  \
# 1501                       5  ...         Ibun                       17
#
#      training_price  discount_training  satisfaction_level training_session  \
# 1501      6500000.0                 30                   5               14
#
#      number_of_participant   training_field  \
# 1501                    10  Training Series
#
#                                           training_name  \
# 1501  Train The Trainer For Outbound (Indoor-outdoor...
#
#                                           cross_selling
# 1501  How to Conduct TNA, Creating Training Material...
#
# [1 rows x 35 columns]

# %%
joblib.dump(model, "./pipeline_save/pipeline7.joblib")
# Out:
# ['./pipeline_save/pipeline7.joblib']
