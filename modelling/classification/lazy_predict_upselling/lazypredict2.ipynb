# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import RobustScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyClassifier

# %%
df = pd.read_csv(r"C:\Users\DHONI HANIF\OneDrive\Documents\AI Sales Cross Selling and UpSelling\data\dataset\Credit & Collection Series.csv")
df.head()
# Out:
#    Unnamed: 0 company_ID          company_name              company_pic  \
# 0           0      P0001   Tribakti Inspektama         Lasmanto Pratiwi
# 1           1      P0002  Bank Bukopin Syariah     Puti Gina Napitupulu
# 2           2      P0003  Bank Bukopin Syariah  Karna Purwanti, S.I.Kom
# 3           3      P0004      Kementrian Agama            Tania Yolanda
# 4           4      P0005                 M3kom        Zaenab Anggriawan
#
#                                      company_address        company_phone  \
# 0  Jalan Cihampelas No. 282\nPontianak, Kalimanta...   +62 (183) 655 1415
# 1    Jalan Tubagus Ismail No. 02\nSukabumi, BB 74318       (097) 773 7113
# 2    Gg. Pelajar Pejuang No. 660\nJambi, Jambi 60449  +62 (0801) 007-5669
# 3               Jl. Cihampelas No. 8\nTual, ST 59647    +62-0247-253-2150
# 4    Gang Moch. Ramdan No. 083\nPayakumbuh, SS 13214       (025) 406 2520
#
#                   company_email  \
# 0  muhammadnasyidah@example.org
# 1     januarkamaria@example.net
# 2         rprasetyo@example.net
# 3    iswahyudiraisa@example.net
# 4         mulyono67@example.com
#
#                                        company_field transaction_date  \
# 0                    Aktivitas Keuangan dan Asuransi       2020-01-01
# 1  Aktivitas Badan Internasional Dan Badan Ekstra...       2020-01-02
# 2  Pengadaan Listrik, Gas, Uap/Air Panas Dan Udar...       2020-01-03
# 3                                         Konstruksi       2020-01-04
# 4                           Informasi Dan Komunikasi       2020-01-05
#
#    level_training_process  ... interest_in_discount_program  training_ID  \
# 0                       5  ...                            5        B0001
# 1                       5  ...                            5        B0002
# 2                       5  ...                            5        B0003
# 3                       5  ...                            5        B0004
# 4                       5  ...                            5        B0005
#
#   trainer_name  training_total_meetings  training_price discount_training  \
# 0         Ibun                       17      6000000.00                50
# 1         Reza                       17      6000000.00                50
# 2         Ibun                       14      6000000.00                50
# 3         Reza                       17      4800000.00                60
# 4        Haris                       17      6000000.00                50
#
#                 training_type  \
# 0  Credit & Collection Series
# 1  Credit & Collection Series
# 2  Credit & Collection Series
# 3  Credit & Collection Series
# 4  Credit & Collection Series
#
#                                      training_name  \
# 0  Mengelola NPL dengan Early Warning System (EWS)
# 1  Mengelola NPL dengan Early Warning System (EWS)
# 2  Mengelola NPL dengan Early Warning System (EWS)
# 3  Mengelola NPL dengan Early Warning System (EWS)
# 4  Mengelola NPL dengan Early Warning System (EWS)
#
#                                        cross_selling  \
# 0  Manajemen Resiko APU & PPT bagi Staff Perbanka...
# 1  Manajemen Resiko APU & PPT bagi Staff Perbanka...
# 2  Manajemen Resiko APU & PPT bagi Staff Perbanka...
# 3  Graphology & Powerful Interview for Credit Ana...
# 4  Manajemen Resiko APU & PPT bagi Staff Perbanka...
#
#                                            upselling
# 0    Mengelola NPL dengan Early Warning System (EWS)
# 1    Mengelola NPL dengan Early Warning System (EWS)
# 2    Mengelola NPL dengan Early Warning System (EWS)
# 3    Mengelola NPL dengan Early Warning System (EWS)
# 4  Manajemen Resiko APU & PPT bagi Staff Perbanka...
#
# [5 rows x 33 columns]

# %%
df = df[["level_training_process", "total_payment", "satisfaction", "complaints",
         "frequency_engagement", "brand_sustainability", "interest_in_discount_program", "training_price",
         "discount_training", "group", "upselling"]]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   level_training_process        5000 non-null   int64
#  1   total_payment                 5000 non-null   float64
#  2   satisfaction                  5000 non-null   int64
#  3   complaints                    5000 non-null   object
#  4   frequency_engagement          5000 non-null   int64
#  5   brand_sustainability          5000 non-null   int64
#  6   interest_in_discount_program  5000 non-null   int64
#  7   training_price                5000 non-null   float64
#  8   discount_training             5000 non-null   int64
#  9   group                         5000 non-null   object
#  10  upselling                     5000 non-null   object
# dtypes: float64(2), int64(6), object(3)
# memory usage: 429.8+ KB

# %%
columns = {}
for i in df.columns:
    if df[i].dtype == "category" or df[i].dtype == "object" :
        columns[i] = LabelEncoder().fit(df[i])
        df[i] = columns[i].transform(df[i])
             
scaler = RobustScaler().fit(df[[i for i in df.columns if i not in columns]])
df2 = pd.DataFrame(scaler.transform(df[[i for i in df.columns if i not in columns]]), columns=df[[i for i in df.columns if i not in columns]].columns)
for i in columns:
    df2[i] = df[i]
df2.head(5)
# Out:
#    level_training_process  total_payment  satisfaction  frequency_engagement  \
# 0                    0.44           0.96          0.44                  0.78
# 1                    0.44           1.07          0.44                  0.78
# 2                    0.44           0.96          0.44                  0.78
# 3                    0.44           0.75          0.44                  0.78
# 4                    0.44           1.07          0.44                  0.78
#
#    brand_sustainability  interest_in_discount_program  training_price  \
# 0                 -0.75                          1.60            0.37
# 1                 -0.75                          1.60            0.37
# 2                 -0.75                          1.60            0.37
# 3                 -1.00                          1.60           -0.30
# 4                 -0.75                          1.60            0.37
#
#    discount_training  complaints  group  upselling
# 0               1.09           2      0          5
# 1               1.09           2      0          5
# 2               1.09           2      0          5
# 3               1.49           2      0          5
# 4               1.09           2      0          4

# %%
X = df2.drop("upselling", axis=1)
y = df2["upselling"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)
reg = LazyClassifier(verbose=0, ignore_warnings=True)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]
#  97%|█████████▋| 28/29 [00:10<00:00,  2.29it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000112 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 196
# [LightGBM] [Info] Number of data points in the train set: 4000, number of used features: 10
# [LightGBM] [Info] Start training from score -2.083450
# [LightGBM] [Info] Start training from score -2.057680
# [LightGBM] [Info] Start training from score -2.071473
# [LightGBM] [Info] Start training from score -2.075450
# [LightGBM] [Info] Start training from score -2.091514
# [LightGBM] [Info] Start training from score -2.107841
# [LightGBM] [Info] Start training from score -2.042146
# [LightGBM] [Info] Start training from score -2.107841
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 100%|██████████| 29/29 [00:11<00:00,  2.44it/s]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# RandomForestClassifier             0.88               0.88    None      0.88
# BaggingClassifier                  0.88               0.88    None      0.88
# LGBMClassifier                     0.88               0.88    None      0.88
# ExtraTreesClassifier               0.87               0.87    None      0.87
# LabelPropagation                   0.87               0.87    None      0.87
# XGBClassifier                      0.87               0.87    None      0.87
# DecisionTreeClassifier             0.87               0.87    None      0.87
# ExtraTreeClassifier                0.86               0.86    None      0.86
# KNeighborsClassifier               0.86               0.86    None      0.86
# SVC                                0.83               0.83    None      0.84
# NuSVC                              0.81               0.81    None      0.81
# LogisticRegression                 0.80               0.80    None      0.80
# QuadraticDiscriminantAnalysis      0.80               0.79    None      0.75
# LinearSVC                          0.74               0.75    None      0.72
# CalibratedClassifierCV             0.74               0.74    None      0.72
# GaussianNB                         0.71               0.71    None      0.64
# LinearDiscriminantAnalysis         0.71               0.71    None      0.68
# SGDClassifier                      0.69               0.69    None      0.68
# RidgeClassifier                    0.68               0.68    None      0.64
# RidgeClassifierCV                  0.68               0.68    None      0.64
# Perceptron                         0.68               0.67    None      0.66
# NearestCentroid                    0.65               0.65    None      0.60
# PassiveAggressiveClassifier        0.61               0.60    None      0.55
# BernoulliNB                        0.45               0.45    None      0.31
# AdaBoostClassifier                 0.36               0.38    None      0.21
# DummyClassifier                    0.11               0.12    None      0.02
#
#                                Time Taken
# Model
# RandomForestClassifier               0.68
# BaggingClassifier                    0.16
# LGBMClassifier                       1.14
# ExtraTreesClassifier                 0.58
# LabelPropagation                     1.38
# XGBClassifier                        1.23
# DecisionTreeClassifier               0.02
# ExtraTreeClassifier                  0.02
# KNeighborsClassifier                 0.11
# SVC                                  0.71
# NuSVC                                2.25
# LogisticRegression                   0.30
# QuadraticDiscriminantAnalysis        0.03
# LinearSVC                            0.57
# CalibratedClassifierCV               0.50
# GaussianNB                           0.03
# LinearDiscriminantAnalysis           0.05
# SGDClassifier                        0.15
# RidgeClassifier                      0.03
# RidgeClassifierCV                    0.03
# Perceptron                           0.08
# NearestCentroid                      0.04
# PassiveAggressiveClassifier          0.09
# BernoulliNB                          0.03
# AdaBoostClassifier                   0.65
# DummyClassifier                      0.01

# %%
def evaluate_performa(X_test, y_test, model1, model2, model3, model4, model5):
    rate = [0, 0, 0, 0, 0]
    #difference = [0, 0, 0, 0, 0]

    X_test = X_test.reset_index(drop=True)
    for i, _ in X_test.iterrows():
        X = np.array(X_test.iloc[[i]])
        y = np.array(y_test.iloc[[i]])
        difference = [0, 0, 0, 0, 0]
        difference[0] = abs(model1.predict(X) - y[0])
        difference[1] = abs(model2.predict(X) - y[0])
        difference[2] = abs(model3.predict(X) - y[0])
        difference[3] = abs(model4.predict(X) - y[0])
        difference[4] = abs(model5.predict(X) - y[0])
        print(difference)

        a = int(np.argmin(difference))
        print(a)
        for i in range(len(difference)):
            if difference[a] == difference[i]:
                rate[i] += 1
    
    a = f"Best model : {rate.index(max(rate))+1}"
    return a, rate

# %%
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, ExtraTreesClassifier
from lightgbm import LGBMClassifier 
from xgboost import XGBClassifier 

forest = RandomForestClassifier()
bagging = BaggingClassifier()
extra = ExtraTreesClassifier()
lgb = LGBMClassifier()
xgb = XGBClassifier()

forest.fit(X_train, y_train)
bagging.fit(X_train, y_train)
extra.fit(X_train, y_train)
lgb.fit(X_train, y_train)
xgb.fit(X_train, y_train)

a = evaluate_performa(X_test, y_test, forest, bagging, extra, lgb, xgb)
a
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000432 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 189
# [LightGBM] [Info] Number of data points in the train set: 4000, number of used features: 10
# [LightGBM] [Info] Start training from score -2.083450
# [LightGBM] [Info] Start training from score -2.057680
# [LightGBM] [Info] Start training from score -2.071473
# [LightGBM] [Info] Start training from score -2.075450
# [LightGBM] [Info] Start training from score -2.091514
# [LightGBM] [Info] Start training from score -2.107841
# [LightGBM] [Info] Start training from score -2.042146
# [LightGBM] [Info] Start training from score -2.107841
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([6]), array([6]), array([6]), array([6]), array([6], dtype=int64)]
# 0
# [array([1]), array([0]), array([1]), array([1]), array([1], dtype=int64)]
# 1
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([3]), array([3]), array([3]), array([3]), array([3], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([3]), array([3]), array([3]), array([3]), array([3], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([6]), array([6], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([3]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([1]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([3]), array([3]), array([3]), array([3]), array([3], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([3]), array([3]), array([3]), array([3]), array([3], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([6]), array([6]), array([6]), array([6]), array([6], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([0]), array([1]), array([0]), array([0], dtype=int64)]
# 1
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([3]), array([3]), array([3]), array([3]), array([3], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([6]), array([6]), array([6]), array([6]), array([6], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([3]), array([3]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([6]), array([6]), array([6]), array([6]), array([6], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([1]), array([0]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([6]), array([6]), array([6]), array([6]), array([6], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([3]), array([3]), array([3]), array([3]), array([3], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([3]), array([3]), array([3]), array([3]), array([3], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([3]), array([3]), array([3]), array([3]), array([3], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([3]), array([3]), array([3]), array([3]), array([3], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([3]), array([3]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([6]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([1]), array([0]), array([1], dtype=int64)]
# 0
# [array([6]), array([6]), array([6]), array([6]), array([6], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([6]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 1
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([3]), array([3]), array([3]), array([3]), array([3], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# ...
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([3]), array([3]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([3]), array([3]), array([3]), array([3]), array([3], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([3]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([3]), array([0]), array([3]), array([3], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([3]), array([3]), array([3]), array([3]), array([3], dtype=int64)]
# 0
# [array([6]), array([0]), array([0]), array([0]), array([6], dtype=int64)]
# 1
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([3]), array([3]), array([3]), array([3]), array([3], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([3]), array([3]), array([3]), array([3]), array([3], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([3]), array([3]), array([3]), array([3]), array([3], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([3]), array([0]), array([3]), array([3], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([6]), array([6]), array([6]), array([6]), array([6], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([1]), array([1]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([4]), array([4]), array([4]), array([4]), array([4], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([1]), array([1]), array([1]), array([1]), array([1], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64)]
# 0
# ('Best model : 1', [996, 992, 990, 992, 988])

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def evaluate2(X_test, y_test, model1, model2, model3, model4, model5):
    result = {
        "Models Name": [],
        "Accuracy": [],
        "Precision Score": [],
        "Recall Score": [],
        "F1 Score": []
    }
    models = [model1, model2, model3, model4, model5]
    for i in range(5):
        y_pred = models[i].predict(X_test)
        result["Models Name"].append(models[i].__class__.__name__)
        result["Accuracy"].append(accuracy_score(y_test, y_pred))
        result["Precision Score"].append(precision_score(y_test, y_pred, average="micro"))
        result["Recall Score"].append(recall_score(y_test, y_pred, average="micro"))
        result["F1 Score"].append(f1_score(y_test, y_pred, average="micro"))
    
    result = pd.DataFrame(result)
    return result

result = evaluate2(X_test, y_test, forest, bagging, extra, lgb, xgb)
result
# Out:
#               Models Name  Accuracy  Precision Score  Recall Score  F1 Score
# 0  RandomForestClassifier      0.88             0.88          0.88      0.88
# 1       BaggingClassifier      0.88             0.88          0.88      0.88
# 2    ExtraTreesClassifier      0.87             0.87          0.87      0.87
# 3          LGBMClassifier      0.88             0.88          0.88      0.88
# 4           XGBClassifier      0.87             0.87          0.87      0.87

# %%
result.plot.barh(x="Models Name")
plt.xlim(0.4, 1.1)
# Out:
# (0.4, 1.1)
