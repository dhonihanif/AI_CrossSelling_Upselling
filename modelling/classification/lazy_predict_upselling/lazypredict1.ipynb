# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import RobustScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyClassifier

# %%
df = pd.read_csv(r"C:\Users\DHONI HANIF\OneDrive\Documents\AI Sales Cross Selling and UpSelling\data\dataset\Sales & Marketing Series.csv")
df.head()
# Out:
#    Unnamed: 0 company_ID          company_name              company_pic  \
# 0           0      P0001   Tribakti Inspektama         Lasmanto Pratiwi
# 1           1      P0002  Bank Bukopin Syariah     Puti Gina Napitupulu
# 2           2      P0003  Bank Bukopin Syariah  Karna Purwanti, S.I.Kom
# 3           3      P0004      Kementrian Agama            Tania Yolanda
# 4           4      P0005                 M3kom        Zaenab Anggriawan
#
#                                      company_address        company_phone  \
# 0  Jalan Cihampelas No. 282\nPontianak, Kalimanta...   +62 (183) 655 1415
# 1    Jalan Tubagus Ismail No. 02\nSukabumi, BB 74318       (097) 773 7113
# 2    Gg. Pelajar Pejuang No. 660\nJambi, Jambi 60449  +62 (0801) 007-5669
# 3               Jl. Cihampelas No. 8\nTual, ST 59647    +62-0247-253-2150
# 4    Gang Moch. Ramdan No. 083\nPayakumbuh, SS 13214       (025) 406 2520
#
#                   company_email  \
# 0  muhammadnasyidah@example.org
# 1     januarkamaria@example.net
# 2         rprasetyo@example.net
# 3    iswahyudiraisa@example.net
# 4         mulyono67@example.com
#
#                                        company_field transaction_date  \
# 0                    Aktivitas Keuangan dan Asuransi       2020-01-01
# 1  Aktivitas Badan Internasional Dan Badan Ekstra...       2020-01-02
# 2  Pengadaan Listrik, Gas, Uap/Air Panas Dan Udar...       2020-01-03
# 3                                         Konstruksi       2020-01-04
# 4                           Informasi Dan Komunikasi       2020-01-05
#
#    level_training_process  ... interest_in_discount_program  training_ID  \
# 0                       5  ...                            5        B0001
# 1                       5  ...                            5        B0002
# 2                       5  ...                            5        B0003
# 3                       5  ...                            5        B0004
# 4                       5  ...                            5        B0005
#
#   trainer_name  training_total_meetings  training_price discount_training  \
# 0         Ibun                       17      5500000.00                50
# 1         Reza                       17      6000000.00                50
# 2         Ibun                       14      6000000.00                50
# 3         Reza                       17      6000000.00                50
# 4        Haris                       17      5500000.00                50
#
#               training_type                                training_name  \
# 0  Sales & Marketing Series  Sales Forecasting: for Sales Target Results
# 1  Sales & Marketing Series  Sales Forecasting: for Sales Target Results
# 2  Sales & Marketing Series  Sales Forecasting: for Sales Target Results
# 3  Sales & Marketing Series  Sales Forecasting: for Sales Target Results
# 4  Sales & Marketing Series  Sales Forecasting: for Sales Target Results
#
#                 cross_selling                                    upselling
# 0  Powerful Closing Technique  Sales Forecasting: for Sales Target Results
# 1  Powerful Closing Technique  Sales Forecasting: for Sales Target Results
# 2  Powerful Closing Technique  Sales Forecasting: for Sales Target Results
# 3  Powerful Closing Technique  Sales Forecasting: for Sales Target Results
# 4  Powerful Closing Technique  Sales Forecasting: for Sales Target Results
#
# [5 rows x 33 columns]

# %%
df.drop([
    "Unnamed: 0", "company_ID", "company_name", "company_pic", "company_address", "company_phone", "company_email",
    "transaction_date", "training_ID", "possibility_of_purchasing_the_same_training", "training_type", "cross_selling",
    "training_name"
    
], axis=1, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   company_field                 5000 non-null   object
#  1   level_training_process        5000 non-null   int64
#  2   purchasing_time_patterns      5000 non-null   object
#  3   number_of_participants        5000 non-null   int64
#  4   group                         5000 non-null   object
#  5   total_payment                 5000 non-null   float64
#  6   satisfaction                  5000 non-null   int64
#  7   communication_channel         5000 non-null   object
#  8   complaints                    5000 non-null   object
#  9   communication_quality         5000 non-null   object
#  10  frequency_engagement          5000 non-null   int64
#  11  brand_sustainability          5000 non-null   int64
#  12  rating_training               5000 non-null   int64
#  13  tren_mode_factor              5000 non-null   object
#  14  interest_in_discount_program  5000 non-null   int64
#  15  trainer_name                  5000 non-null   object
#  16  training_total_meetings       5000 non-null   int64
#  17  training_price                5000 non-null   float64
#  18  discount_training             5000 non-null   int64
#  19  upselling                     5000 non-null   object
# dtypes: float64(2), int64(9), object(9)
# memory usage: 781.4+ KB

# %%
columns = {}
for i in df.columns:
    if df[i].dtype == "category" or df[i].dtype == "object" :
        columns[i] = LabelEncoder().fit(df[i])
        df[i] = columns[i].transform(df[i])
             
scaler = RobustScaler().fit(df[[i for i in df.columns if i not in columns]])
df2 = pd.DataFrame(scaler.transform(df[[i for i in df.columns if i not in columns]]), columns=df[[i for i in df.columns if i not in columns]].columns)
for i in columns:
    df2[i] = df[i]
df2.head(5)
# Out:
#    level_training_process  number_of_participants  total_payment  \
# 0                    0.44                    0.44           1.00
# 1                    0.44                    0.56           0.96
# 2                    0.44                    0.11           0.96
# 3                    0.44                    1.11           1.18
# 4                    0.44                    0.78           1.00
#
#    satisfaction  frequency_engagement  brand_sustainability  rating_training  \
# 0          0.44                  0.78                 -1.00             0.50
# 1          0.44                  0.78                 -0.75             0.50
# 2          0.44                  0.78                 -0.75             0.00
# 3          0.44                  0.78                 -0.75             0.50
# 4          0.44                  0.78                 -1.00             0.50
#
#    interest_in_discount_program  training_total_meetings  training_price  \
# 0                          1.60                     0.50            0.08
# 1                          1.60                     0.50            0.36
# 2                          1.60                     0.00            0.36
# 3                          1.60                     0.50            0.36
# 4                          1.60                     0.50            0.08
#
#    discount_training  company_field  purchasing_time_patterns  group  \
# 0               1.09              4                         1      0
# 1               1.09              1                         1      0
# 2               1.09             14                         1      0
# 3               1.09             12                         1      0
# 4               1.09             10                         1      0
#
#    communication_channel  complaints  communication_quality  tren_mode_factor  \
# 0                      2           2                      0                 1
# 1                      2           2                      0                 1
# 2                      2           2                      0                 1
# 3                      2           2                      0                 1
# 4                      2           2                      0                 1
#
#    trainer_name  upselling
# 0             3          6
# 1             6          6
# 2             3          6
# 3             6          6
# 4             2          6

# %%
X = df2.drop("upselling", axis=1)
y = df2["upselling"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)
reg = LazyClassifier(verbose=0, ignore_warnings=True)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
#   0%|          | 0/29 [00:00<?, ?it/s]
#  97%|█████████▋| 28/29 [00:14<00:00,  2.38it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001297 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 286
# [LightGBM] [Info] Number of data points in the train set: 4000, number of used features: 19
# [LightGBM] [Info] Start training from score -2.059639
# [LightGBM] [Info] Start training from score -2.044074
# [LightGBM] [Info] Start training from score -2.095571
# [LightGBM] [Info] Start training from score -2.091514
# [LightGBM] [Info] Start training from score -2.069491
# [LightGBM] [Info] Start training from score -2.093540
# [LightGBM] [Info] Start training from score -2.107841
# [LightGBM] [Info] Start training from score -2.075450
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 100%|██████████| 29/29 [00:15<00:00,  1.82it/s]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     1.00               1.00    None      1.00
# ExtraTreesClassifier               1.00               1.00    None      1.00
# RandomForestClassifier             1.00               1.00    None      1.00
# XGBClassifier                      1.00               1.00    None      1.00
# BaggingClassifier                  1.00               1.00    None      1.00
# DecisionTreeClassifier             1.00               1.00    None      1.00
# ExtraTreeClassifier                0.97               0.97    None      0.97
# LogisticRegression                 0.94               0.94    None      0.94
# SVC                                0.89               0.89    None      0.89
# NuSVC                              0.89               0.89    None      0.89
# CalibratedClassifierCV             0.83               0.83    None      0.82
# LinearSVC                          0.83               0.83    None      0.81
# LinearDiscriminantAnalysis         0.79               0.80    None      0.77
# SGDClassifier                      0.79               0.79    None      0.76
# PassiveAggressiveClassifier        0.78               0.79    None      0.78
# Perceptron                         0.76               0.77    None      0.75
# RidgeClassifier                    0.76               0.77    None      0.73
# RidgeClassifierCV                  0.76               0.77    None      0.73
# GaussianNB                         0.70               0.71    None      0.64
# LabelSpreading                     0.70               0.69    None      0.70
# LabelPropagation                   0.70               0.69    None      0.70
# KNeighborsClassifier               0.68               0.68    None      0.68
# NearestCentroid                    0.64               0.64    None      0.60
# QuadraticDiscriminantAnalysis      0.56               0.55    None      0.48
# BernoulliNB                        0.51               0.51    None      0.43
# AdaBoostClassifier                 0.36               0.38    None      0.20
# DummyClassifier                    0.11               0.12    None      0.02
#
#                                Time Taken
# Model
# LGBMClassifier                       1.12
# ExtraTreesClassifier                 0.70
# RandomForestClassifier               0.67
# XGBClassifier                        0.74
# BaggingClassifier                    0.25
# DecisionTreeClassifier               0.05
# ExtraTreeClassifier                  0.03
# LogisticRegression                   0.35
# SVC                                  1.04
# NuSVC                                2.49
# CalibratedClassifierCV               1.24
# LinearSVC                            0.67
# LinearDiscriminantAnalysis           0.05
# SGDClassifier                        0.16
# PassiveAggressiveClassifier          0.13
# Perceptron                           0.09
# RidgeClassifier                      0.03
# RidgeClassifierCV                    0.03
# GaussianNB                           0.04
# LabelSpreading                       2.39
# LabelPropagation                     2.17
# KNeighborsClassifier                 0.67
# NearestCentroid                      0.03
# QuadraticDiscriminantAnalysis        0.04
# BernoulliNB                          0.04
# AdaBoostClassifier                   0.60
# DummyClassifier                      0.03

# %%
def evaluate_performa(X_test, y_test, model1, model2, model3, model4, model5, model6, model7):
    rate = [0, 0, 0, 0, 0, 0, 0]
    #difference = [0, 0, 0, 0, 0]

    X_test = X_test.reset_index(drop=True)
    for i, _ in X_test.iterrows():
        X = np.array(X_test.iloc[[i]])
        y = np.array(y_test.iloc[[i]])
        difference = [0, 0, 0, 0, 0, 0, 0]
        difference[0] = abs(model1.predict(X) - y[0])
        difference[1] = abs(model2.predict(X) - y[0])
        difference[2] = abs(model3.predict(X) - y[0])
        difference[3] = abs(model4.predict(X) - y[0])
        difference[4] = abs(model5.predict(X) - y[0])
        difference[5] = abs(model6.predict(X) - y[0])
        difference[6] = abs(model7.predict(X) - y[0])
        print(difference)

        a = int(np.argmin(difference))
        print(a)
        for i in range(len(difference)):
            if difference[a] == difference[i]:
                rate[i] += 1
    
    a = f"Best model : {rate.index(max(rate))+1}"
    return a, rate

# %%
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, ExtraTreesClassifier
from lightgbm import LGBMClassifier 
from xgboost import XGBClassifier 
from sklearn.svm import SVC
from sklearn.naive_bayes import BernoulliNB

forest = RandomForestClassifier()
bagging = BaggingClassifier()
extra = ExtraTreesClassifier()
lgb = LGBMClassifier()
xgb = XGBClassifier()
nb = BernoulliNB()
svc = SVC()

forest.fit(X_train, y_train)
bagging.fit(X_train, y_train)
extra.fit(X_train, y_train)
lgb.fit(X_train, y_train)
xgb.fit(X_train, y_train)
nb.fit(X_train, y_train)
svc.fit(X_train, y_train)

a = evaluate_performa(X_test, y_test, forest, bagging, extra, lgb, xgb, nb, svc)
a
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000179 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 269
# [LightGBM] [Info] Number of data points in the train set: 4000, number of used features: 19
# [LightGBM] [Info] Start training from score -2.059639
# [LightGBM] [Info] Start training from score -2.044074
# [LightGBM] [Info] Start training from score -2.095571
# [LightGBM] [Info] Start training from score -2.091514
# [LightGBM] [Info] Start training from score -2.069491
# [LightGBM] [Info] Start training from score -2.093540
# [LightGBM] [Info] Start training from score -2.107841
# [LightGBM] [Info] Start training from score -2.075450
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([4]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([1]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([4]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([1]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([5]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([4]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([4]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([1]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([7]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([4]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([4]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([5]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([7])]
# 0
# ...
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([2], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([7]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([5]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([5]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([1]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([2]), array([2])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([0]), array([0])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([3])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([7]), array([7])]
# 0
# [array([0]), array([0]), array([0]), array([0]), array([0], dtype=int64), array([3]), array([0])]
# 0
# ('Best model : 1', [1000, 1000, 1000, 1000, 999, 628, 674])

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def evaluate2(X_test, y_test, model1, model2, model3, model4, model5, model6, model7):
    result = {
        "Models Name": [],
        "Accuracy": [],
        "Precision Score": [],
        "Recall Score": [],
        "F1 Score": []
    }
    models = [model1, model2, model3, model4, model5, model6, model7]
    for i in range(7):
        y_pred = models[i].predict(X_test)
        result["Models Name"].append(models[i].__class__.__name__)
        result["Accuracy"].append(accuracy_score(y_test, y_pred))
        result["Precision Score"].append(precision_score(y_test, y_pred, average="micro"))
        result["Recall Score"].append(recall_score(y_test, y_pred, average="micro"))
        result["F1 Score"].append(f1_score(y_test, y_pred, average="micro"))
    
    result = pd.DataFrame(result)
    return result

result = evaluate2(X_test, y_test, forest, bagging, extra, lgb, xgb, nb, svc)
result
# Out:
#               Models Name  Accuracy  Precision Score  Recall Score  F1 Score
# 0  RandomForestClassifier      1.00             1.00          1.00      1.00
# 1       BaggingClassifier      1.00             1.00          1.00      1.00
# 2    ExtraTreesClassifier      1.00             1.00          1.00      1.00
# 3          LGBMClassifier      1.00             1.00          1.00      1.00
# 4           XGBClassifier      1.00             1.00          1.00      1.00
# 5             BernoulliNB      0.63             0.63          0.63      0.63
# 6                     SVC      0.67             0.67          0.67      0.67

# %%
result.plot.barh(x="Models Name")
plt.xlim(0.6, 1.1)
# Out:
# (0.6, 1.1)
