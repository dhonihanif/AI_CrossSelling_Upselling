# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, OrdinalEncoder
from sklearn.pipeline import Pipeline  
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve

# %%
df = pd.read_csv(r"C:\Users\DHONI HANIF\OneDrive\Documents\AI Sales Cross Selling and UpSelling\data\dataset\Credit & Collection Series.csv")
df.head()
# Out:
#    Unnamed: 0 company_ID          company_name              company_pic  \
# 0           0      P0001   Tribakti Inspektama         Lasmanto Pratiwi
# 1           1      P0002  Bank Bukopin Syariah     Puti Gina Napitupulu
# 2           2      P0003  Bank Bukopin Syariah  Karna Purwanti, S.I.Kom
# 3           3      P0004      Kementrian Agama            Tania Yolanda
# 4           4      P0005                 M3kom        Zaenab Anggriawan
#
#                                      company_address        company_phone  \
# 0  Jalan Cihampelas No. 282\nPontianak, Kalimanta...   +62 (183) 655 1415
# 1    Jalan Tubagus Ismail No. 02\nSukabumi, BB 74318       (097) 773 7113
# 2    Gg. Pelajar Pejuang No. 660\nJambi, Jambi 60449  +62 (0801) 007-5669
# 3               Jl. Cihampelas No. 8\nTual, ST 59647    +62-0247-253-2150
# 4    Gang Moch. Ramdan No. 083\nPayakumbuh, SS 13214       (025) 406 2520
#
#                   company_email  \
# 0  muhammadnasyidah@example.org
# 1     januarkamaria@example.net
# 2         rprasetyo@example.net
# 3    iswahyudiraisa@example.net
# 4         mulyono67@example.com
#
#                                        company_field transaction_date  \
# 0                    Aktivitas Keuangan dan Asuransi       2020-01-01
# 1  Aktivitas Badan Internasional Dan Badan Ekstra...       2020-01-02
# 2  Pengadaan Listrik, Gas, Uap/Air Panas Dan Udar...       2020-01-03
# 3                                         Konstruksi       2020-01-04
# 4                           Informasi Dan Komunikasi       2020-01-05
#
#    level_training_process  ... training_total_meetings  training_price  \
# 0                       5  ...                      17       6000000.0
# 1                       5  ...                      17       4800000.0
# 2                       5  ...                      14       6000000.0
# 3                       5  ...                      17       4800000.0
# 4                       5  ...                      17       6000000.0
#
#   discount_training  satisfaction_level  training_session  \
# 0                50                   5                17
# 1                60                   5                17
# 2                50                   5                17
# 3                60                   5                17
# 4                50                   5                17
#
#   number_of_participant              training_field  \
# 0                    18  Credit & Collection Series
# 1                    19  Credit & Collection Series
# 2                    20  Credit & Collection Series
# 3                    19  Credit & Collection Series
# 4                    20  Credit & Collection Series
#
#                                      training_name  \
# 0  Mengelola NPL dengan Early Warning System (EWS)
# 1  Mengelola NPL dengan Early Warning System (EWS)
# 2  Mengelola NPL dengan Early Warning System (EWS)
# 3  Mengelola NPL dengan Early Warning System (EWS)
# 4  Mengelola NPL dengan Early Warning System (EWS)
#
#                                        cross_selling  \
# 0  Graphology & Powerful Interview for Credit Ana...
# 1  Manajemen Resiko APU & PPT bagi Staff Perbanka...
# 2  Manajemen Resiko APU & PPT bagi Staff Perbanka...
# 3  Manajemen Resiko APU & PPT bagi Staff Perbanka...
# 4  Manajemen Resiko APU & PPT bagi Staff Perbanka...
#
#                                          upselling
# 0  Mengelola NPL dengan Early Warning System (EWS)
# 1  Mengelola NPL dengan Early Warning System (EWS)
# 2  Mengelola NPL dengan Early Warning System (EWS)
# 3  Mengelola NPL dengan Early Warning System (EWS)
# 4  Mengelola NPL dengan Early Warning System (EWS)
#
# [5 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 36 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Unnamed: 0                                   5000 non-null   int64
#  1   company_ID                                   5000 non-null   object
#  2   company_name                                 5000 non-null   object
#  3   company_pic                                  5000 non-null   object
#  4   company_address                              5000 non-null   object
#  5   company_phone                                5000 non-null   object
#  6   company_email                                5000 non-null   object
#  7   company_field                                5000 non-null   object
#  8   transaction_date                             5000 non-null   object
#  9   level_training_process                       5000 non-null   int64
#  10  purchasing_time_patterns                     5000 non-null   object
#  11  number_of_participants                       5000 non-null   int64
#  12  group                                        5000 non-null   object
#  13  total_payment                                5000 non-null   float64
#  14  satisfaction                                 5000 non-null   int64
#  15  communication_channel                        5000 non-null   object
#  16  complaints                                   5000 non-null   object
#  17  communication_quality                        5000 non-null   object
#  18  possibility_of_purchasing_the_same_training  5000 non-null   int64
#  19  frequency_engagement                         5000 non-null   int64
#  20  brand_sustainability                         5000 non-null   int64
#  21  rating_training                              5000 non-null   int64
#  22  tren_mode_factor                             5000 non-null   object
#  23  interest_in_discount_program                 5000 non-null   int64
#  24  training_ID                                  5000 non-null   object
#  25  trainer_name                                 5000 non-null   object
#  26  training_total_meetings                      5000 non-null   int64
#  27  training_price                               5000 non-null   float64
#  28  discount_training                            5000 non-null   int64
#  29  satisfaction_level                           5000 non-null   int64
#  30  training_session                             5000 non-null   int64
#  31  number_of_participant                        5000 non-null   int64
#  32  training_field                               5000 non-null   object
#  33  training_name                                5000 non-null   object
#  34  cross_selling                                5000 non-null   object
#  35  upselling                                    5000 non-null   object
# dtypes: float64(2), int64(14), object(20)
# memory usage: 1.4+ MB

# %%
for i in df.columns:
    if df[i].dtype == "object":
        df[i] = df[i].astype("category")

# %%
# Preprocessing untuk fitur kategori
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ordinal', OrdinalEncoder())
])

# Preprocessing untuk fitur numerik
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', MinMaxScaler())
])

numeric_features = ["level_training_process", "possibility_of_purchasing_the_same_training", "satisfaction_level",
                    "frequency_engagement", "number_of_participant", "training_session"]

categorical_features = ["group", "communication_channel", "complaints", "training_name"]


drop_features = ["Unnamed: 0", "company_ID", "company_name", "company_pic", "company_address", "company_phone", "company_email", "company_field",
                 "transaction_date", "purchasing_time_patterns", "communication_quality", "total_payment", "brand_sustainability", "rating_training",
                 "interest_in_discount_program", "training_ID", "tren_mode_factor", "training_price", "discount_training", "training_field",
                 "trainer_name", "upselling"]

# Gabungkan transformer dengan ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features),
        ('drop', 'drop', drop_features)
    ],
    remainder="passthrough"
    )

# %%
X = df.drop("cross_selling", axis=1)
y = df["cross_selling"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

pkl = joblib.load(r"C:\Users\DHONI HANIF\OneDrive\Documents\AI Sales Cross Selling and UpSelling\modelling\classification\cross_selling\model_save\model2.pkl")
model = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("models", pkl)
])
model.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000101 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 191
# [LightGBM] [Info] Number of data points in the train set: 4000, number of used features: 13
# [LightGBM] [Info] Start training from score -2.103734
# [LightGBM] [Info] Start training from score -2.103734
# [LightGBM] [Info] Start training from score -2.075450
# [LightGBM] [Info] Start training from score -2.059639
# [LightGBM] [Info] Start training from score -2.085460
# [LightGBM] [Info] Start training from score -2.105786
# [LightGBM] [Info] Start training from score -2.055725
# [LightGBM] [Info] Start training from score -2.047943
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   ['level_training_process',
#                                                    'possibility_of_purchasing_the_same_training',
#                                                    'satisfaction_level',
#                                                    'frequency_engagement',
#                                                    'number_of_participant',
#                                                    'training_session']),
#                                                  ('cat',
#                                                   Pipeline(steps=...
#                                                    'transaction_date',
#                                                    'purchasing_time_patterns',
#                                                    'communication_quality',
#                                                    'total_payment',
#                                                    'brand_sustainability',
#                                                    'rating_training',
#                                                    'interest_in_discount_program',
#                                                    'training_ID',
#                                                    'tren_mode_factor',
#                                                    'training_price',
#                                                    'discount_training',
#                                                    'training_field',
#                                                    'trainer_name',
#                                                    'upselling'])])),
#                 ('models',
#                  LGBMClassifier(learning_rate=0.01, max_depth=5,
#                                 n_estimators=50, num_leaves=15))])

# %%
y_pred = model.predict(X_test)
fig, ax = plt.subplots(1, 2, figsize=(10, 5), layout="constrained")
sns.heatmap(confusion_matrix(y_train, model.predict(X_train)), annot=True, fmt="d", linecolor="white", linewidths=0.2, cmap="winter", ax=ax[0])
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt="d", linecolor="white", linewidths=0.2, cmap="winter", ax=ax[1])

ax[0].set_title("Training")
ax[1].set_title("Testing")
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#                                                                                        precision    recall  f1-score   support
#
#                                                    Debt Collection Strategy & Tactics       0.93      0.91      0.92       124
#                                    Graphology & Powerful Interview for Credit Analyst       0.93      0.88      0.91       139
#        How to detect & prevent application fraud in Digital Era for Banking & Fintech       0.94      0.93      0.94       116
#                                                         Managing Corporate Collection       0.93      0.94      0.94       122
# Manajemen Resiko APU & PPT bagi Staff Perbankan, Multifinance, sekuritas dan asuransi       0.87      0.90      0.89       120
#                                       Mengelola NPL dengan Early Warning System (EWS)       0.90      0.94      0.92       126
#                                                Restrukturisasi Kredit for SME Lending       0.90      0.93      0.91       132
#                              Teknik Penyelesaian Kredit & Pemasaran AYDA yang Efektif       0.94      0.89      0.92       121
#
#                                                                              accuracy                           0.92      1000
#                                                                             macro avg       0.92      0.92      0.92      1000
#                                                                          weighted avg       0.92      0.92      0.92      1000

# %%
a = model.predict_proba(X_test.iloc[:1, :])
b = ["Debt Collection Strategy & Tactics", "Graphology & Powerful Interview for Credit Analyst",
     "How to detect & prevent application fraud in Digital Era for Banking & Fintech", "Managing Corporate Collection",
     "Manajemen Resiko APU & PPT bagi Staff Perbankan, Multifinance, sekuritas dan asuransi",
     "Mengelola NPL dengan Early Warning System (EWS)", "Restrukturisasi Kredit for SME Lending", "Teknik Penyelesaian Kredit & Pemasaran AYDA yang Efektif"]

for i, j in zip(b, a.ravel()):
    print(i, f"{j*100:.2f}%")
# Out:
# Debt Collection Strategy & Tactics 6.92%
# Graphology & Powerful Interview for Credit Analyst 6.92%
# How to detect & prevent application fraud in Digital Era for Banking & Fintech 7.11%
# Managing Corporate Collection 7.22%
# Manajemen Resiko APU & PPT bagi Staff Perbankan, Multifinance, sekuritas dan asuransi 7.06%
# Mengelola NPL dengan Early Warning System (EWS) 44.97%
# Restrukturisasi Kredit for SME Lending 7.25%
# Teknik Penyelesaian Kredit & Pemasaran AYDA yang Efektif 12.55%

# %%
model.predict(X_test.iloc[:1, :])
# Out:
# array(['Mengelola NPL dengan Early Warning System (EWS)'], dtype=object)

# %%
y_test.iloc[0]
# Out:
# 'Mengelola NPL dengan Early Warning System (EWS)'

# %%
joblib.dump(model, "./pipeline_save/pipeline2.joblib")
# Out:
# ['./pipeline_save/pipeline2.joblib']
