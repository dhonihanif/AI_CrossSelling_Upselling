# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\DHONI HANIF\OneDrive\Documents\AI Sales Cross Selling and UpSelling\data\AI Sales Cross Selling and UpSelling.csv")
df.head()
# Out:
#    Unnamed: 0 company_ID          company_name              company_pic  \
# 0           0      P0001   Tribakti Inspektama         Lasmanto Pratiwi
# 1           1      P0002  Bank Bukopin Syariah     Puti Gina Napitupulu
# 2           2      P0003  Bank Bukopin Syariah  Karna Purwanti, S.I.Kom
# 3           3      P0004      Kementrian Agama            Tania Yolanda
# 4           4      P0005                 M3kom        Zaenab Anggriawan
#
#                                      company_address        company_phone  \
# 0  Jalan Cihampelas No. 282\nPontianak, Kalimanta...   +62 (183) 655 1415
# 1    Jalan Tubagus Ismail No. 02\nSukabumi, BB 74318       (097) 773 7113
# 2    Gg. Pelajar Pejuang No. 660\nJambi, Jambi 60449  +62 (0801) 007-5669
# 3               Jl. Cihampelas No. 8\nTual, ST 59647    +62-0247-253-2150
# 4    Gang Moch. Ramdan No. 083\nPayakumbuh, SS 13214       (025) 406 2520
#
#                   company_email  \
# 0  muhammadnasyidah@example.org
# ...

# %%
df.drop([
    "Unnamed: 0", "company_ID", "company_name", "company_pic", "company_address", "company_phone", "company_email",
    "transaction_date", "training_ID"
], axis=1, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   company_field                                5000 non-null   object
#  1   level_training_process                       5000 non-null   int64
#  2   purchasing_time_patterns                     5000 non-null   object
#  3   number_of_participants                       5000 non-null   int64
#  4   group                                        5000 non-null   object
#  5   total_payment                                5000 non-null   float64
#  6   satisfaction                                 5000 non-null   int64
#  7   communication_channel                        5000 non-null   object
#  8   complaints                                   5000 non-null   object
# ...

# %%
for i in df.columns:
    if df[i].dtype == "object":
        df[i] = df[i].astype("category")

# %% [markdown]
# ### company field vs purchasing time patterns

# %%
ax = sns.countplot(data=df, x="company_field", hue="purchasing_time_patterns")
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment="right")
plt.legend(bbox_to_anchor=(1, 0.2))
plt.tight_layout()
plt.show()
# Out:
# C:\Users\DHONI HANIF\AppData\Local\Temp\ipykernel_16068\382742017.py:5: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ### Purchasing Time Patterns vs Group

# %%
ax = sns.countplot(data=df, x="purchasing_time_patterns", hue="group")
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment="right")
plt.legend(bbox_to_anchor=(1, 0.2))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Communication_channel vs Complaints

# %%
ax = sns.countplot(data=df, x="communication_channel", hue="complaints")
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment="right")
plt.legend(bbox_to_anchor=(1, 0.2))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Communication_channel vs communication_quality

# %%
ax = sns.countplot(data=df, x="communication_channel", hue="communication_quality")
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment="right")
plt.legend(bbox_to_anchor=(1, 0.2))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### tren_mode_factor vs level_training_process

# %%
ax = sns.countplot(data=df, x="level_training_process", hue="tren_mode_factor")
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment="right")
plt.legend(bbox_to_anchor=(1, 0.2))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### purchasing_time_patterns vs tren_mode_factor

# %%
ax = sns.countplot(data=df, x="purchasing_time_patterns", hue="tren_mode_factor")
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment="right")
plt.legend(bbox_to_anchor=(1, 0.2))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### level_training_process vs purchasing_time_patterns

# %%
sns.boxplot(data=df, x="purchasing_time_patterns", y="level_training_process")
# Out:
# <Axes: xlabel='purchasing_time_patterns', ylabel='level_training_process'>

# %% [markdown]
# ### Purchasing_time_patterns vs number_of_participants

# %%
sns.boxplot(data=df, x="purchasing_time_patterns", y="number_of_participants")
# Out:
# <Axes: xlabel='purchasing_time_patterns', ylabel='number_of_participants'>

# %% [markdown]
# ### Communication_channel vs level_training_process

# %%
sns.boxplot(data=df, x="communication_channel", y="level_training_process")
# Out:
# <Axes: xlabel='communication_channel', ylabel='level_training_process'>

# %% [markdown]
# ### Complaints vs level_training_process

# %%
sns.boxplot(data=df, x="complaints", y="level_training_process")
# Out:
# <Axes: xlabel='complaints', ylabel='level_training_process'>

# %% [markdown]
# ### Complaints vs rating_training

# %%
sns.boxplot(data=df, x="complaints", y="rating_training")
# Out:
# <Axes: xlabel='complaints', ylabel='rating_training'>

# %% [markdown]
# ### Complaints vs frequency_engagement

# %%
sns.boxplot(data=df, x="complaints", y="frequency_engagement")
# Out:
# <Axes: xlabel='complaints', ylabel='frequency_engagement'>

# %% [markdown]
# ### Communication quality vs frequency_engagement

# %%
sns.boxplot(data=df, x="communication_quality", y="frequency_engagement")
# Out:
# <Axes: xlabel='communication_quality', ylabel='frequency_engagement'>

# %% [markdown]
# ### communication_channel vs frequency_engagement

# %%
sns.boxplot(data=df, x="communication_channel", y="frequency_engagement")
# Out:
# <Axes: xlabel='communication_channel', ylabel='frequency_engagement'>

# %% [markdown]
# ### prefered_category vs possibility_of_purchasing_the_same_training

# %%
sns.boxplot(data=df, x="prefered_category", y="possibility_of_purchasing_the_same_training")
plt.xticks(rotation=15)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'Credit & Collection Series'),
#   Text(1, 0, 'Finance Series'),
#   Text(2, 0, 'HR Series'),
#   Text(3, 0, 'Leadership & Managerial Series'),
#   Text(4, 0, 'Office & Administration Series'),
#   Text(5, 0, 'Other Series'),
#   Text(6, 0, 'Sales & Marketing Series'),
#   Text(7, 0, 'Training Series')])

# %% [markdown]
# ### prefered_category vs satisfaction

# %%
sns.boxplot(data=df, x="prefered_category", y="satisfaction")
plt.xticks(rotation=15)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  [Text(0, 0, 'Credit & Collection Series'),
#   Text(1, 0, 'Finance Series'),
#   Text(2, 0, 'HR Series'),
#   Text(3, 0, 'Leadership & Managerial Series'),
#   Text(4, 0, 'Office & Administration Series'),
#   Text(5, 0, 'Other Series'),
#   Text(6, 0, 'Sales & Marketing Series'),
#   Text(7, 0, 'Training Series')])

# %% [markdown]
# ### satisfaction vs frequency_engagement

# %%
sns.lineplot(data=df, x="satisfaction", y="frequency_engagement")
# Out:
# <Axes: xlabel='satisfaction', ylabel='frequency_engagement'>

# %% [markdown]
# ### satisfaction vs rating_training

# %%
sns.lineplot(data=df, x="satisfaction", y="rating_training")
# Out:
# <Axes: xlabel='satisfaction', ylabel='rating_training'>

# %% [markdown]
# ### satisfaction vs possibility_of_purchasing_the_same_training

# %%
sns.lineplot(data=df, x="satisfaction", y="possibility_of_purchasing_the_same_training")
# Out:
# <Axes: xlabel='satisfaction', ylabel='possibility_of_purchasing_the_same_training'>

# %% [markdown]
# ### possibility_of_purchasing_the_same_training vs brand_sustainability

# %%
sns.lineplot(data=df, x="brand_sustainability", y="possibility_of_purchasing_the_same_training")
# Out:
# <Axes: xlabel='brand_sustainability', ylabel='possibility_of_purchasing_the_same_training'>

# %% [markdown]
# ### level_training_process vs possibility_of_purchasing_the_same_training

# %%
sns.lineplot(data=df, x="level_training_process", y="possibility_of_purchasing_the_same_training")
# Out:
# <Axes: xlabel='level_training_process', ylabel='possibility_of_purchasing_the_same_training'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   company_field                                5000 non-null   category
#  1   level_training_process                       5000 non-null   int64
#  2   purchasing_time_patterns                     5000 non-null   category
#  3   number_of_participants                       5000 non-null   int64
#  4   group                                        5000 non-null   category
#  5   total_payment                                5000 non-null   float64
#  6   satisfaction                                 5000 non-null   int64
#  7   communication_channel                        5000 non-null   category
#  8   complaints                                   5000 non-null   category
# ...

# %%
num_columns = [i for i in df.columns if df[i].dtype != "category"]
fig, ax = plt.subplots(figsize=(20, 15))
sns.heatmap(data=df[num_columns].corr(), annot=True, linewidths=.2, linecolor="white", cmap="winter", ax=ax)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
# Scaling category variable

columns = {}
for i in df.columns:
    if df[i].dtype == "category" or df[i].dtype == "object":
        columns[i] = LabelEncoder().fit(df[i])
        df[i] = columns[i].transform(df[i])
 
fig, ax = plt.subplots(figsize=(20, 15))
sns.heatmap(data=df.corr(), annot=True, linewidths=.2, linecolor="white", cmap="winter", ax=ax)
# Out:
# <Axes: >
