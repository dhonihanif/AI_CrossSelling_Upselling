# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\DHONI HANIF\OneDrive\Documents\AI Sales Cross Selling and UpSelling\data\dataset\Credit & Collection Series.csv")
df.head()
# Out:
#    Unnamed: 0 company_ID          company_name              company_pic  \
# 0           0      P0001   Tribakti Inspektama         Lasmanto Pratiwi
# 1           1      P0002  Bank Bukopin Syariah     Puti Gina Napitupulu
# 2           2      P0003  Bank Bukopin Syariah  Karna Purwanti, S.I.Kom
# 3           3      P0004      Kementrian Agama            Tania Yolanda
# 4           4      P0005                 M3kom        Zaenab Anggriawan
#
#                                      company_address        company_phone  \
# 0  Jalan Cihampelas No. 282\nPontianak, Kalimanta...   +62 (183) 655 1415
# 1    Jalan Tubagus Ismail No. 02\nSukabumi, BB 74318       (097) 773 7113
# 2    Gg. Pelajar Pejuang No. 660\nJambi, Jambi 60449  +62 (0801) 007-5669
# 3               Jl. Cihampelas No. 8\nTual, ST 59647    +62-0247-253-2150
# 4    Gang Moch. Ramdan No. 083\nPayakumbuh, SS 13214       (025) 406 2520
#
#                   company_email  \
# 0  muhammadnasyidah@example.org
# 1     januarkamaria@example.net
# 2         rprasetyo@example.net
# 3    iswahyudiraisa@example.net
# 4         mulyono67@example.com
#
#                                        company_field transaction_date  \
# 0                    Aktivitas Keuangan dan Asuransi       2020-01-01
# 1  Aktivitas Badan Internasional Dan Badan Ekstra...       2020-01-02
# 2  Pengadaan Listrik, Gas, Uap/Air Panas Dan Udar...       2020-01-03
# 3                                         Konstruksi       2020-01-04
# 4                           Informasi Dan Komunikasi       2020-01-05
#
#    level_training_process  ... interest_in_discount_program  training_ID  \
# 0                       2  ...                            2        B0001
# 1                       3  ...                            2        B0002
# 2                       4  ...                            4        B0003
# 3                       2  ...                            3        B0004
# 4                       5  ...                            5        B0005
#
#   trainer_name  training_total_meetings  training_price discount_training  \
# 0         Alam                        8         3000000                 0
# 1         Reza                       11         4000000                10
# 2        Haris                       14        11000000                25
# 3         Reza                       11        11000000                10
# 4        Haris                       17        11000000                50
#
#                 training_type  \
# 0  Credit & Collection Series
# 1  Credit & Collection Series
# 2  Credit & Collection Series
# 3  Credit & Collection Series
# 4  Credit & Collection Series
#
#                                        training_name  \
# 0    Mengelola NPL dengan Early Warning System (EWS)
# 1  How to detect & prevent application fraud in D...
# 2                      Managing Corporate Collection
# 3  How to detect & prevent application fraud in D...
# 4  Graphology & Powerful Interview for Credit Ana...
#
#                                        cross_selling  \
# 0                      Managing Corporate Collection
# 1  How to detect & prevent application fraud in D...
# 2  Manajemen Resiko APU & PPT bagi Staff Perbanka...
# 3  How to detect & prevent application fraud in D...
# 4  How to detect & prevent application fraud in D...
#
#                                            upselling
# 0  Manajemen Resiko APU & PPT bagi Staff Perbanka...
# 1                      Managing Corporate Collection
# 2  Graphology & Powerful Interview for Credit Ana...
# 3                      Managing Corporate Collection
# 4  How to detect & prevent application fraud in D...
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Univariatee Analysis

# %%
# training_name
fig, ax = plt.subplots(figsize=(20, 8), layout="constrained")
sns.histplot(data=df["training_name"], ax=ax)
ax.set_title("Nama Training")
plt.xticks(rotation=15)
plt.show()
print(df["training_name"].value_counts())
# Out:
# How to detect & prevent application fraud in Digital Era for Banking & Fintech           1491
# Graphology & Powerful Interview for Credit Analyst                                       1114
# Managing Corporate Collection                                                             970
# Mengelola NPL dengan Early Warning System (EWS)                                           685
# Manajemen Resiko APU & PPT bagi Staff Perbankan, Multifinance, sekuritas dan asuransi     525
# Restrukturisasi Kredit for SME Lending                                                     81
# Debt Collection Strategy & Tactics                                                         74
# Teknik Penyelesaian Kredit & Pemasaran AYDA yang Efektif                                   60
# Name: training_name, dtype: int64

# %%
# Cross Selling
fig, ax = plt.subplots(figsize=(20, 8), layout="constrained")
sns.histplot(data=df["cross_selling"], ax=ax)
ax.set_title("Nama Training")
plt.xticks(rotation=15)
plt.show()
print(df["cross_selling"].value_counts())
# Out:
# How to detect & prevent application fraud in Digital Era for Banking & Fintech           1502
# Restrukturisasi Kredit for SME Lending                                                   1143
# Manajemen Resiko APU & PPT bagi Staff Perbankan, Multifinance, sekuritas dan asuransi     934
# Managing Corporate Collection                                                             682
# Debt Collection Strategy & Tactics                                                        505
# Mengelola NPL dengan Early Warning System (EWS)                                            82
# Teknik Penyelesaian Kredit & Pemasaran AYDA yang Efektif                                   82
# Graphology & Powerful Interview for Credit Analyst                                         70
# Name: cross_selling, dtype: int64

# %%
# Upselling
fig, ax = plt.subplots(figsize=(20, 8), layout="constrained")
sns.histplot(data=df["upselling"], ax=ax)
ax.set_title("Upselling")
plt.xticks(rotation=15)
plt.show()
print(df["upselling"].value_counts())
# Out:
# Managing Corporate Collection                                                            1542
# How to detect & prevent application fraud in Digital Era for Banking & Fintech           1144
# Graphology & Powerful Interview for Credit Analyst                                        916
# Manajemen Resiko APU & PPT bagi Staff Perbankan, Multifinance, sekuritas dan asuransi     678
# Teknik Penyelesaian Kredit & Pemasaran AYDA yang Efektif                                  508
# Mengelola NPL dengan Early Warning System (EWS)                                            77
# Debt Collection Strategy & Tactics                                                         72
# Restrukturisasi Kredit for SME Lending                                                     63
# Name: upselling, dtype: int64
