# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\DHONI HANIF\OneDrive\Documents\AI Sales Cross Selling and UpSelling\data\dataset\Credit & Collection Series.csv")
df.head()
# Out:
#    Unnamed: 0 company_ID          company_name              company_pic  \
# 0           0      P0001   Tribakti Inspektama         Lasmanto Pratiwi
# 1           1      P0002  Bank Bukopin Syariah     Puti Gina Napitupulu
# 2           2      P0003  Bank Bukopin Syariah  Karna Purwanti, S.I.Kom
# 3           3      P0004      Kementrian Agama            Tania Yolanda
# 4           4      P0005                 M3kom        Zaenab Anggriawan
#
#                                      company_address        company_phone  \
# 0  Jalan Cihampelas No. 282\nPontianak, Kalimanta...   +62 (183) 655 1415
# 1    Jalan Tubagus Ismail No. 02\nSukabumi, BB 74318       (097) 773 7113
# 2    Gg. Pelajar Pejuang No. 660\nJambi, Jambi 60449  +62 (0801) 007-5669
# 3               Jl. Cihampelas No. 8\nTual, ST 59647    +62-0247-253-2150
# 4    Gang Moch. Ramdan No. 083\nPayakumbuh, SS 13214       (025) 406 2520
#
#                   company_email  \
# 0  muhammadnasyidah@example.org
# 1     januarkamaria@example.net
# 2         rprasetyo@example.net
# 3    iswahyudiraisa@example.net
# 4         mulyono67@example.com
#
#                                        company_field transaction_date  \
# 0                    Aktivitas Keuangan dan Asuransi       2020-01-01
# 1  Aktivitas Badan Internasional Dan Badan Ekstra...       2020-01-02
# 2  Pengadaan Listrik, Gas, Uap/Air Panas Dan Udar...       2020-01-03
# 3                                         Konstruksi       2020-01-04
# 4                           Informasi Dan Komunikasi       2020-01-05
#
#    level_training_process  ... training_total_meetings  training_price  \
# 0                       5  ...                      17       6000000.0
# 1                       5  ...                      17       5500000.0
# 2                       5  ...                      14       6000000.0
# 3                       5  ...                      17       5500000.0
# 4                       5  ...                      17       6000000.0
#
#   discount_training  satisfaction_level  training_session  \
# 0                50                   5                17
# 1                50                   5                16
# 2                50                   5                17
# 3                50                   5                16
# 4                50                   5                17
#
#   number_of_perticipant               training_type  \
# 0                    20  Credit & Collection Series
# 1                    19  Credit & Collection Series
# 2                    19  Credit & Collection Series
# 3                    18  Credit & Collection Series
# 4                    18  Credit & Collection Series
#
#                                      training_name  \
# 0  Mengelola NPL dengan Early Warning System (EWS)
# 1  Mengelola NPL dengan Early Warning System (EWS)
# 2  Mengelola NPL dengan Early Warning System (EWS)
# 3  Mengelola NPL dengan Early Warning System (EWS)
# 4  Mengelola NPL dengan Early Warning System (EWS)
#
#                                        cross_selling  \
# 0  Manajemen Resiko APU & PPT bagi Staff Perbanka...
# 1  Manajemen Resiko APU & PPT bagi Staff Perbanka...
# 2  Graphology & Powerful Interview for Credit Ana...
# 3  Manajemen Resiko APU & PPT bagi Staff Perbanka...
# 4  Graphology & Powerful Interview for Credit Ana...
#
#                                          upselling
# 0  Mengelola NPL dengan Early Warning System (EWS)
# 1  Mengelola NPL dengan Early Warning System (EWS)
# 2  Mengelola NPL dengan Early Warning System (EWS)
# 3  Mengelola NPL dengan Early Warning System (EWS)
# 4  Mengelola NPL dengan Early Warning System (EWS)
#
# [5 rows x 36 columns]

# %% [markdown]
# ## Univariatee Analysis

# %%
# training_name
fig, ax = plt.subplots(figsize=(20, 8), layout="constrained")
sns.histplot(data=df["training_name"], ax=ax)
ax.set_title("Nama Training")
plt.xticks(rotation=15)
plt.show()
print(df["training_name"].value_counts())
# Out:
# Mengelola NPL dengan Early Warning System (EWS)                                          625
# Manajemen Resiko APU & PPT bagi Staff Perbankan, Multifinance, sekuritas dan asuransi    625
# Graphology & Powerful Interview for Credit Analyst                                       625
# Restrukturisasi Kredit for SME Lending                                                   625
# Debt Collection Strategy & Tactics                                                       625
# Teknik Penyelesaian Kredit & Pemasaran AYDA yang Efektif                                 625
# How to detect & prevent application fraud in Digital Era for Banking & Fintech           625
# Managing Corporate Collection                                                            625
# Name: training_name, dtype: int64

# %%
# Cross Selling
fig, ax = plt.subplots(figsize=(20, 8), layout="constrained")
sns.histplot(data=df["cross_selling"], ax=ax)
ax.set_title("Nama Training")
plt.xticks(rotation=15)
plt.show()
print(df["cross_selling"].value_counts())
# Out:
# How to detect & prevent application fraud in Digital Era for Banking & Fintech           637
# Manajemen Resiko APU & PPT bagi Staff Perbankan, Multifinance, sekuritas dan asuransi    631
# Mengelola NPL dengan Early Warning System (EWS)                                          628
# Graphology & Powerful Interview for Credit Analyst                                       627
# Debt Collection Strategy & Tactics                                                       623
# Teknik Penyelesaian Kredit & Pemasaran AYDA yang Efektif                                 622
# Restrukturisasi Kredit for SME Lending                                                   619
# Managing Corporate Collection                                                            613
# Name: cross_selling, dtype: int64

# %%
# Upselling
fig, ax = plt.subplots(figsize=(20, 8), layout="constrained")
sns.histplot(data=df["upselling"], ax=ax)
ax.set_title("Upselling")
plt.xticks(rotation=15)
plt.show()
print(df["upselling"].value_counts())
# Out:
# Mengelola NPL dengan Early Warning System (EWS)                                          650
# Graphology & Powerful Interview for Credit Analyst                                       640
# Restrukturisasi Kredit for SME Lending                                                   634
# Managing Corporate Collection                                                            625
# Teknik Penyelesaian Kredit & Pemasaran AYDA yang Efektif                                 620
# How to detect & prevent application fraud in Digital Era for Banking & Fintech           616
# Debt Collection Strategy & Tactics                                                       615
# Manajemen Resiko APU & PPT bagi Staff Perbankan, Multifinance, sekuritas dan asuransi    600
# Name: upselling, dtype: int64

# %%
num_columns = [i for i in df.columns if df[i].dtype != "object"]
fig, ax = plt.subplots(figsize=(20, 15))
sns.heatmap(data=df[num_columns].corr(), annot=True, linewidths=.2, linecolor="white", cmap="winter", ax=ax)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
# Scaling category variable

columns = {}
for i in df.columns:
    if df[i].dtype == "category" or df[i].dtype == "object":
        columns[i] = LabelEncoder().fit(df[i])
        df[i] = columns[i].transform(df[i])

df.drop([
    "Unnamed: 0", "company_ID", "company_name", "company_pic", "company_address", "company_phone", "company_email",
    "transaction_date", "training_type", "training_ID"
], axis=1, inplace=True)

fig, ax = plt.subplots(figsize=(20, 15))
sns.heatmap(data=df.corr(), annot=True, linewidths=.2, linecolor="white", cmap="winter", ax=ax)
# Out:
# <Axes: >
