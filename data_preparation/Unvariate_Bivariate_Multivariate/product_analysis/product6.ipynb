# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\DHONI HANIF\OneDrive\Documents\AI Sales Cross Selling and UpSelling\data\dataset\Leadership & Managerial Series.csv")
df.head()
# Out:
#    Unnamed: 0 company_ID          company_name              company_pic  \
# 0           0      P0001   Tribakti Inspektama         Lasmanto Pratiwi
# 1           1      P0002  Bank Bukopin Syariah     Puti Gina Napitupulu
# 2           2      P0003  Bank Bukopin Syariah  Karna Purwanti, S.I.Kom
# 3           3      P0004      Kementrian Agama            Tania Yolanda
# 4           4      P0005                 M3kom        Zaenab Anggriawan
#
#                                      company_address        company_phone  \
# 0  Jalan Cihampelas No. 282\nPontianak, Kalimanta...   +62 (183) 655 1415
# 1    Jalan Tubagus Ismail No. 02\nSukabumi, BB 74318       (097) 773 7113
# 2    Gg. Pelajar Pejuang No. 660\nJambi, Jambi 60449  +62 (0801) 007-5669
# 3               Jl. Cihampelas No. 8\nTual, ST 59647    +62-0247-253-2150
# 4    Gang Moch. Ramdan No. 083\nPayakumbuh, SS 13214       (025) 406 2520
#
#                   company_email  \
# 0  muhammadnasyidah@example.org
# 1     januarkamaria@example.net
# 2         rprasetyo@example.net
# 3    iswahyudiraisa@example.net
# 4         mulyono67@example.com
#
#                                        company_field transaction_date  \
# 0                    Aktivitas Keuangan dan Asuransi       2020-01-01
# 1  Aktivitas Badan Internasional Dan Badan Ekstra...       2020-01-02
# 2  Pengadaan Listrik, Gas, Uap/Air Panas Dan Udar...       2020-01-03
# 3                                         Konstruksi       2020-01-04
# 4                           Informasi Dan Komunikasi       2020-01-05
#
#    level_training_process  ... interest_in_discount_program  training_ID  \
# 0                       5  ...                            5        B0001
# 1                       5  ...                            5        B0002
# 2                       5  ...                            5        B0003
# 3                       5  ...                            5        B0004
# 4                       5  ...                            5        B0005
#
#   trainer_name  training_total_meetings  training_price discount_training  \
# 0         Ibun                       17         4000000                50
# 1         Reza                       17        11000000                50
# 2         Ibun                       14         7000000                50
# 3         Reza                       17        11000000                60
# 4        Haris                       17        10000000                50
#
#                     training_type  \
# 0  Leadership & Managerial Series
# 1  Leadership & Managerial Series
# 2  Leadership & Managerial Series
# 3  Leadership & Managerial Series
# 4  Leadership & Managerial Series
#
#                                        training_name  \
# 0  Agile Leadership What Leaders Have To Do in En...
# 1  Agile Leadership What Leaders Have To Do in En...
# 2  Agile Leadership What Leaders Have To Do in En...
# 3  Agile Leadership What Leaders Have To Do in En...
# 4  Agile Leadership What Leaders Have To Do in En...
#
#                                        cross_selling  \
# 0  Infografis & Pembuatan Materi Presentasi bagi ...
# 1  Modern Leadership Skills: How Leaders Managing...
# 2  Modern Leadership Skills: How Leaders Managing...
# 3  Infografis & Pembuatan Materi Presentasi bagi ...
# 4  Infografis & Pembuatan Materi Presentasi bagi ...
#
#                                            upselling
# 0  Infografis & Pembuatan Materi Presentasi bagi ...
# 1  Agile Leadership What Leaders Have To Do in En...
# 2  Agile Leadership What Leaders Have To Do in En...
# 3  Agile Leadership What Leaders Have To Do in En...
# 4  Infografis & Pembuatan Materi Presentasi bagi ...
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Univariatee Analysis

# %%
# training_name
fig, ax = plt.subplots(figsize=(20, 8), layout="constrained")
sns.histplot(data=df["training_name"], ax=ax)
ax.set_title("Nama Training")
plt.xticks(rotation=15)
plt.show()
print(df["training_name"].value_counts())
# Out:
# Agile Leadership What Leaders Have To Do in Enabling Agile Transformation              625
# Infografis & Pembuatan Materi Presentasi bagi Level Manajemen                          625
# Modern Leadership Skills: How Leaders Managing Team by Data in the Era of Analytics    625
# Distance Coaching & Mentoring using Digital Approach                                   625
# Analisa Data & Penampilannya bagi Presentase Manajemen                                 625
# Modern Project Management: Combining Scrum & Sprint                                    625
# Five Core Leadership Using POCE                                                        625
# Winning Negotiation Skills                                                             625
# Name: training_name, dtype: int64

# %%
# Cross Selling
fig, ax = plt.subplots(figsize=(20, 8), layout="constrained")
sns.histplot(data=df["cross_selling"], ax=ax)
ax.set_title("Nama Training")
plt.xticks(rotation=15)
plt.show()
print(df["cross_selling"].value_counts())
# Out:
# Agile Leadership What Leaders Have To Do in Enabling Agile Transformation              632
# Winning Negotiation Skills                                                             632
# Analisa Data & Penampilannya bagi Presentase Manajemen                                 632
# Infografis & Pembuatan Materi Presentasi bagi Level Manajemen                          630
# Modern Leadership Skills: How Leaders Managing Team by Data in the Era of Analytics    628
# Modern Project Management: Combining Scrum & Sprint                                    618
# Five Core Leadership Using POCE                                                        618
# Distance Coaching & Mentoring using Digital Approach                                   610
# Name: cross_selling, dtype: int64

# %%
# Upselling
fig, ax = plt.subplots(figsize=(20, 8), layout="constrained")
sns.histplot(data=df["upselling"], ax=ax)
ax.set_title("Upselling")
plt.xticks(rotation=15)
plt.show()
print(df["upselling"].value_counts())
# Out:
# Winning Negotiation Skills                                                             637
# Distance Coaching & Mentoring using Digital Approach                                   635
# Modern Leadership Skills: How Leaders Managing Team by Data in the Era of Analytics    633
# Infografis & Pembuatan Materi Presentasi bagi Level Manajemen                          632
# Analisa Data & Penampilannya bagi Presentase Manajemen                                 627
# Agile Leadership What Leaders Have To Do in Enabling Agile Transformation              618
# Five Core Leadership Using POCE                                                        615
# Modern Project Management: Combining Scrum & Sprint                                    603
# Name: upselling, dtype: int64

# %%
num_columns = [i for i in df.columns if df[i].dtype != "object"]
fig, ax = plt.subplots(figsize=(20, 15))
sns.heatmap(data=df[num_columns].corr(), annot=True, linewidths=.2, linecolor="white", cmap="winter", ax=ax)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
# Scaling category variable

columns = {}
for i in df.columns:
    if df[i].dtype == "category" or df[i].dtype == "object":
        columns[i] = LabelEncoder().fit(df[i])
        df[i] = columns[i].transform(df[i])

df.drop([
    "Unnamed: 0", "company_ID", "company_name", "company_pic", "company_address", "company_phone", "company_email",
    "transaction_date", "training_type", "training_ID"
], axis=1, inplace=True)

fig, ax = plt.subplots(figsize=(20, 15))
sns.heatmap(data=df.corr(), annot=True, linewidths=.2, linecolor="white", cmap="winter", ax=ax)
# Out:
# <Axes: >
