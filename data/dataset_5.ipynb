# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./AI Sales Cross Selling and UpSelling.csv")
df.head()
# Out:
#    Unnamed: 0 company_ID          company_name              company_pic  \
# 0           0      P0001   Tribakti Inspektama         Lasmanto Pratiwi
# 1           1      P0002  Bank Bukopin Syariah     Puti Gina Napitupulu
# 2           2      P0003  Bank Bukopin Syariah  Karna Purwanti, S.I.Kom
# 3           3      P0004      Kementrian Agama            Tania Yolanda
# 4           4      P0005                 M3kom        Zaenab Anggriawan
#
#                                      company_address        company_phone  \
# 0  Jalan Cihampelas No. 282\nPontianak, Kalimanta...   +62 (183) 655 1415
# 1    Jalan Tubagus Ismail No. 02\nSukabumi, BB 74318       (097) 773 7113
# 2    Gg. Pelajar Pejuang No. 660\nJambi, Jambi 60449  +62 (0801) 007-5669
# 3               Jl. Cihampelas No. 8\nTual, ST 59647    +62-0247-253-2150
# 4    Gang Moch. Ramdan No. 083\nPayakumbuh, SS 13214       (025) 406 2520
#
#                   company_email  \
# 0  muhammadnasyidah@example.org
# ...

# %%
df.drop(["Unnamed: 0", "prefered_category", "training_type", "training_name", "cross_selling", "upselling"], axis=1, inplace=True)
df.head()
# Out:
#   company_ID          company_name              company_pic  \
# 0      P0001   Tribakti Inspektama         Lasmanto Pratiwi
# 1      P0002  Bank Bukopin Syariah     Puti Gina Napitupulu
# 2      P0003  Bank Bukopin Syariah  Karna Purwanti, S.I.Kom
# 3      P0004      Kementrian Agama            Tania Yolanda
# 4      P0005                 M3kom        Zaenab Anggriawan
#
#                                      company_address        company_phone  \
# 0  Jalan Cihampelas No. 282\nPontianak, Kalimanta...   +62 (183) 655 1415
# 1    Jalan Tubagus Ismail No. 02\nSukabumi, BB 74318       (097) 773 7113
# 2    Gg. Pelajar Pejuang No. 660\nJambi, Jambi 60449  +62 (0801) 007-5669
# 3               Jl. Cihampelas No. 8\nTual, ST 59647    +62-0247-253-2150
# 4    Gang Moch. Ramdan No. 083\nPayakumbuh, SS 13214       (025) 406 2520
#
#                   company_email  \
# 0  muhammadnasyidah@example.org
# 1     januarkamaria@example.net
# 2         rprasetyo@example.net
# ...

# %%
office = []
cross_selling = []
upselling = []
data_office = [
    "Interactive Dashboard with Microsoft Excel", # 5
    "Electronic Filing Management With Simple Database Software & Apps", # 5
    "Powerful Database Analysis & Dashboard Reporting with Microsoft Excel", # 4
    "Secretary Development Program", # 1
    "Manajemen Filing & Tata Kelola Kantor", # 3
    "Electronic Filing & Document Management System", # 4
    "Excel & Powerpoint For Powerful Business Applications", # 2
    "Managing General Affairs Excellence" # 3
]

for i in range(5000):
    if i <= 624:
        office.append(data_office[0])
    elif i <= 1249:
        office.append(data_office[1])
    elif i <= 1874:
        office.append(data_office[2])
    elif i <= 2499:
        office.append(data_office[3])
    elif i <= 3124:
        office.append(data_office[4])
    elif i <= 3749:
        office.append(data_office[5])
    elif i <= 4374:
        office.append(data_office[6])
    else:
        office.append(data_office[7])

# %%
satisfaction = []
level_training_process = []
purchasing_time_patterns = []
communication_channel = []
complaints = []
communication_quality = []
possibility_of_purchasing_the_same_training = []
frequency_engagement = []
brand_sustainability = []
rating_training = []
tren_mode_factor = []
interest_in_discount_program = []
training_total_meetings = []
training_price = []
total_payment = []
number_of_participants = []
diskon = []
group = []

dictt = {
    "Interactive Dashboard with Microsoft Excel": 12000000, # 5
    "Electronic Filing Management With Simple Database Software & Apps": 10000000, # 5
    "Powerful Database Analysis & Dashboard Reporting with Microsoft Excel": 8000000, # 4
    "Secretary Development Program": 3000000, # 1
    "Manajemen Filing & Tata Kelola Kantor": 6500000, # 3
    "Electronic Filing & Document Management System": 7500000, # 4
    "Excel & Powerpoint For Powerful Business Applications": 4000000, # 2
    "Managing General Affairs Excellence": 7000000 # 3
    
}
for i in range(len(df)):
    if office[i] == data_office[0]:
        if i <= 312:
            cross_selling.append(np.random.choice([data_office[1], data_office[2]], p=[0.9, 0.1]))
            upselling.append(np.random.choice([data_office[0], data_office[1]], p=[0.9, 0.1]))
            diskon.append(np.random.choice([50, 60], p=[0.9, 0.1]))
            group.append("Group")
            number_of_participants.append(np.random.randint(18, 21))
            training_total_meetings.append(np.random.choice([16, 17], p=[0.1, 0.9]))
            harga = dictt[office[i]] - (dictt[office[i]]*(diskon[-1]/100)) - (500000*(17-training_total_meetings[-1]))
            satisfaction.append(5)
            level_training_process.append(5)
            purchasing_time_patterns.append("diskon")
            communication_channel.append("social media")
            complaints.append("positif")
            communication_quality.append("bagus")
            possibility_of_purchasing_the_same_training.append(np.random.randint(85, 95))
            frequency_engagement.append(10)
            brand_sustainability.append(np.random.randint(1, 3))
            rating_training.append(5)
            tren_mode_factor.append("Ya")
            interest_in_discount_program.append(5)
        else:
            cross_selling.append(np.random.choice([data_office[1], data_office[2]], p=[0.1, 0.9]))
            upselling.append(np.random.choice([data_office[0], data_office[1]], p=[0.1, 0.9]))
            diskon.append(np.random.choice([40, 45], p=[0.9, 0.1]))
            group.append("Group")
            number_of_participants.append(np.random.randint(15, 17))
            training_total_meetings.append(np.random.choice([16, 17], p=[0.9, 0.1]))
            harga = dictt[office[i]] - (dictt[office[i]]*(diskon[-1]/100)) - (500000*(17-training_total_meetings[-1]))
            satisfaction.append(np.random.choice([4, 5], p=[0.2, 0.8]))
            level_training_process.append(5)
            purchasing_time_patterns.append("diskon")
            communication_channel.append("social media")
            complaints.append("positif")
            communication_quality.append("bagus")
            possibility_of_purchasing_the_same_training.append(np.random.randint(75, 85))
            frequency_engagement.append(10)
            brand_sustainability.append(np.random.randint(1, 3))
            rating_training.append(5)
            tren_mode_factor.append("Ya")
            interest_in_discount_program.append(5)
    elif office[i] == data_office[1]:
        if i <= 938:
            cross_selling.append(np.random.choice([data_office[0], data_office[5]], p=[0.9, 0.1]))
            upselling.append(np.random.choice([data_office[1], data_office[0]], p=[0.9, 0.1]))
            diskon.append(np.random.choice([35, 38], p=[0.1, 0.9]))
            group.append("Group")
            number_of_participants.append(np.random.randint(15, 18))
            training_total_meetings.append(np.random.choice([14, 15], p=[0.1, 0.9]))
            harga = dictt[office[i]] - (dictt[office[i]]*(diskon[-1]/100)) - (500000*(15-training_total_meetings[-1]))
            satisfaction.append(np.random.choice([4, 5], p=[0.1, 0.9]))
            level_training_process.append(np.random.choice([4, 5], p=[0.1, 0.9]))
            purchasing_time_patterns.append(np.random.choice(["peristiwa khusus", "diskon"], p=[0.1, 0.9]))
            communication_channel.append(np.random.choice(["social media", "phone"], p=[0.9, 0.1]))
            complaints.append("positif")
            communication_quality.append("bagus")
            possibility_of_purchasing_the_same_training.append(np.random.randint(70, 75))
            frequency_engagement.append(10)
            brand_sustainability.append(1)
            rating_training.append(np.random.choice([4, 5], p=[0.1, 0.9]))
            tren_mode_factor.append("Ya")
            interest_in_discount_program.append(np.random.randint(4, 6))
        else:
            cross_selling.append(np.random.choice([data_office[0], data_office[5]], p=[0.1, 0.9]))
            upselling.append(np.random.choice([data_office[1], data_office[0]], p=[0.1, 0.9]))
            diskon.append(np.random.choice([35, 40], p=[0.9, 0.1]))
            group.append("Group")
            number_of_participants.append(np.random.randint(15, 18))
            training_total_meetings.append(np.random.choice([14, 15], p=[0.9, 0.1]))
            harga = dictt[office[i]] - (dictt[office[i]]*(diskon[-1]/100)) - (500000*(15-training_total_meetings[-1]))
            satisfaction.append(np.random.choice([4, 5], p=[0.9, 0.1]))
            level_training_process.append(np.random.choice([4, 5], p=[0.1, 0.9]))
            purchasing_time_patterns.append(np.random.choice(["peristiwa khusus", "diskon"], p=[0.1, 0.9]))
            communication_channel.append(np.random.choice(["social media", "phone"], p=[0.9, 0.1]))
            complaints.append(np.random.choice(["positif", "netral"], p=[0.9, 0.1]))
            communication_quality.append(np.random.choice(["bagus", "sedang"], p=[0.9, 0.1]))
            possibility_of_purchasing_the_same_training.append(np.random.randint(65, 70))
            frequency_engagement.append(9)
            brand_sustainability.append(2)
            rating_training.append(np.random.choice([4, 5], p=[0.1, 0.9]))
            tren_mode_factor.append(np.random.choice(["Ya", "Tidak"], p=[0.9, 0.1]))
            interest_in_discount_program.append(np.random.randint(4, 6))
    elif office[i] == data_office[2]:
        if i <= 1561:
            cross_selling.append(np.random.choice([data_office[0], data_office[5]], p=[0.9, 0.1]))
            upselling.append(np.random.choice([data_office[5], data_office[2]], p=[0.9, 0.1]))
            diskon.append(np.random.choice([30, 33], p=[0.1, 0.9]))
            group.append("Group")
            number_of_participants.append(np.random.randint(13, 16))
            training_total_meetings.append(np.random.choice([13, 14], p=[0.1, 0.9]))
            harga = dictt[office[i]] - (dictt[office[i]]*(diskon[-1]/100)) - (300000*(14-training_total_meetings[-1]))
            satisfaction.append(np.random.choice([4, 5], p=[0.4, 0.6]))
            level_training_process.append(np.random.choice([4, 5], p=[0.9, 0.1]))
            purchasing_time_patterns.append(np.random.choice(["musiman", "peristiwa khusus", "diskon"], p=[0.1, 0.1, 0.8]))
            communication_channel.append(np.random.choice(["social media", "phone"], p=[0.7, 0.3]))
            complaints.append(np.random.choice(["positif", "netral"], p=[0.7, 0.3]))
            communication_quality.append(np.random.choice(["bagus", "sedang"], p=[0.7, 0.3]))
            possibility_of_purchasing_the_same_training.append(np.random.randint(60, 65))
            frequency_engagement.append(8)
            brand_sustainability.append(3)
            rating_training.append(np.random.choice([4, 5], p=[0.4, 0.6]))
            tren_mode_factor.append(np.random.choice(["Ya", "Tidak"], p=[0.9, 0.1]))
            interest_in_discount_program.append(4)
        else:
            cross_selling.append(np.random.choice([data_office[0], data_office[5]], p=[0.1, 0.9]))
            upselling.append(np.random.choice([data_office[5], data_office[2]], p=[0.1, 0.9]))
            diskon.append(np.random.choice([30, 33], p=[0.9, 0.1]))
            group.append("Group")
            number_of_participants.append(np.random.randint(10, 13))
            training_total_meetings.append(np.random.choice([13, 14], p=[0.9, 0.1]))
            harga = dictt[office[i]] - (dictt[office[i]]*(diskon[-1]/100)) - (300000*(14-training_total_meetings[-1]))
            satisfaction.append(np.random.choice([4, 5], p=[0.6, 0.4]))
            level_training_process.append(np.random.choice([4, 5], p=[0.9, 0.1]))
            purchasing_time_patterns.append(np.random.choice(["musiman", "peristiwa khusus", "diskon"], p=[0.2, 0.2, 0.6]))
            communication_channel.append(np.random.choice(["social media", "phone"], p=[0.6, 0.4]))
            complaints.append(np.random.choice(["positif", "netral"], p=[0.7, 0.3]))
            communication_quality.append(np.random.choice(["bagus", "sedang"], p=[0.7, 0.3]))
            possibility_of_purchasing_the_same_training.append(np.random.randint(55, 60))
            frequency_engagement.append(np.random.randint(8, 10))
            brand_sustainability.append(np.random.randint(3, 5))
            rating_training.append(np.random.choice([4, 5], p=[0.9, 0.1]))
            tren_mode_factor.append(np.random.choice(["Ya", "Tidak"], p=[0.9, 0.1]))
            interest_in_discount_program.append(np.random.randint(3, 5))
    elif office[i] == data_office[3]:
        if i <= 2186:
            cross_selling.append(np.random.choice([data_office[-2], data_office[-1]], p=[0.9, 0.1]))
            upselling.append(np.random.choice([data_office[6], data_office[3]], p=[0.9, 0.1]))
            diskon.append(0)
            group.append("Retail")
            number_of_participants.append(np.random.randint(1, 3))
            training_total_meetings.append(7)
            harga = dictt[office[i]] - (dictt[office[i]]*(diskon[-1]/100)) - (50000*(7-training_total_meetings[-1]))
            satisfaction.append(np.random.choice([1, 2], p=[0.1, 0.9]))
            level_training_process.append(np.random.choice([1, 2], p=[0.1, 0.9]))
            purchasing_time_patterns.append(np.random.choice(["bulan", "hari spesifik"], p=[0.4, 0.6]))
            communication_channel.append(np.random.choice(["email", "phone"], p=[0.9, 0.1]))
            complaints.append(np.random.choice(["negatif", "netral"], p=[0.9, 0.1]))
            communication_quality.append(np.random.choice(["buruk", "sedang"], p=[0.9, 0.1]))
            possibility_of_purchasing_the_same_training.append(np.random.randint(10, 15))
            frequency_engagement.append(1)
            brand_sustainability.append(10)
            rating_training.append(np.random.choice([1, 2], p=[0.9, 0.1]))
            tren_mode_factor.append("Tidak")
            interest_in_discount_program.append(1)
        else:
            cross_selling.append(np.random.choice([data_office[-2], data_office[-1]], p=[0.1, 0.9]))
            upselling.append(np.random.choice([data_office[6], data_office[3]], p=[0.1, 0.9]))
            diskon.append(0)
            group.append("Retail")
            number_of_participants.append(np.random.randint(1, 3))
            training_total_meetings.append(6)
            harga = dictt[office[i]] - (dictt[office[i]]*(diskon[-1]/100)) - (50000*(7-training_total_meetings[-1]))
            satisfaction.append(np.random.choice([1, 2], p=[0.9, 0.1]))
            level_training_process.append(np.random.choice([1, 2], p=[0.9, 0.1]))
            purchasing_time_patterns.append(np.random.choice(["bulan", "hari spesifik"], p=[0.4, 0.6]))
            communication_channel.append(np.random.choice(["email", "phone"], p=[0.9, 0.1]))
            complaints.append(np.random.choice(["negatif", "netral"], p=[0.9, 0.1]))
            communication_quality.append(np.random.choice(["buruk", "sedang"], p=[0.9, 0.1]))
            possibility_of_purchasing_the_same_training.append(np.random.randint(5, 10))
            frequency_engagement.append(2)
            brand_sustainability.append(10)
            rating_training.append(np.random.choice([1, 2], p=[0.7, 0.3]))
            tren_mode_factor.append("Tidak")
            interest_in_discount_program.append(1)
    elif office[i] == data_office[4]:
        if i <= 2812:
            cross_selling.append(np.random.choice([data_office[-1], data_office[-2]], p=[0.9, 0.1]))
            upselling.append(np.random.choice([data_office[2], data_office[4]], p=[0.9, 0.1]))
            diskon.append(np.random.choice([18, 20], p=[0.2, 0.8]))
            group.append(np.random.choice(["Group", "Retail"], p=[0.8, 0.2]))
            number_of_participants.append(np.random.randint(6, 11))
            training_total_meetings.append(11)
            harga = dictt[office[i]] - (dictt[office[i]]*(diskon[-1]/100)) - (100000*(11-training_total_meetings[-1]))
            satisfaction.append(np.random.choice([3, 4], p=[0.8, 0.2]))
            level_training_process.append(np.random.choice([3, 4], p=[0.6, 0.4]))
            purchasing_time_patterns.append(np.random.choice(["bulan", "hari spesifik", "diskon"], p=[0.2, 0.2, 0.6]))
            communication_channel.append(np.random.choice(["social media", "phone"], p=[0.4, 0.6]))
            complaints.append(np.random.choice(["positif", "netral", "negatif"], p=[0.6, 0.3, 0.1]))
            communication_quality.append(np.random.choice(["bagus", "sedang", "buruk"], p=[0.1, 0.8, 0.1]))
            possibility_of_purchasing_the_same_training.append(np.random.randint(52, 55))
            frequency_engagement.append(6)
            brand_sustainability.append(6)
            rating_training.append(np.random.choice([3, 4], p=[0.4, 0.6]))
            tren_mode_factor.append(np.random.choice(["Ya", "Tidak"], p=[0.8, 0.2]))
            interest_in_discount_program.append(3)
        else:
            cross_selling.append(np.random.choice([data_office[-1], data_office[-2]], p=[0.1, 0.9]))
            upselling.append(np.random.choice([data_office[2], data_office[4]], p=[0.1, 0.9]))
            diskon.append(np.random.choice([15, 17], p=[0.9, 0.1]))
            group.append(np.random.choice(["Group", "Retail"], p=[0.7, 0.3]))
            number_of_participants.append(np.random.randint(6, 11))
            training_total_meetings.append(10)
            harga = dictt[office[i]] - (dictt[office[i]]*(diskon[-1]/100)) - (100000*(11-training_total_meetings[-1]))
            satisfaction.append(np.random.choice([3, 4], p=[0.8, 0.2]))
            level_training_process.append(np.random.choice([3, 4], p=[0.6, 0.4]))
            purchasing_time_patterns.append(np.random.choice(["bulan", "hari spesifik", "diskon"], p=[0.2, 0.2, 0.6]))
            communication_channel.append(np.random.choice(["social media", "phone"], p=[0.4, 0.6]))
            complaints.append(np.random.choice(["positif", "netral", "negatif"], p=[0.6, 0.3, 0.1]))
            communication_quality.append(np.random.choice(["bagus", "sedang", "buruk"], p=[0.1, 0.8, 0.1]))
            possibility_of_purchasing_the_same_training.append(np.random.randint(50, 52))
            frequency_engagement.append(5)
            brand_sustainability.append(6)
            rating_training.append(np.random.choice([3, 4], p=[0.6, 0.4]))
            tren_mode_factor.append(np.random.choice(["Ya", "Tidak"], p=[0.8, 0.2]))
            interest_in_discount_program.append(3)
    elif office[i] == data_office[5]:
        if i <= 3437:
            cross_selling.append(np.random.choice([data_office[4], data_office[2]], p=[0.9, 0.1]))
            upselling.append(np.random.choice([data_office[-1], data_office[5]], p=[0.9, 0.1]))
            diskon.append(np.random.choice([25, 30], p=[0.1, 0.9]))
            group.append("Group")
            number_of_participants.append(np.random.randint(13, 16))
            training_total_meetings.append(np.random.choice([11, 12], p=[0.1, 0.9]))
            harga = dictt[office[i]] - (dictt[office[i]]*(diskon[-1]/100)) - (300000*(12-training_total_meetings[-1]))
            satisfaction.append(np.random.choice([4, 5], p=[0.4, 0.6]))
            level_training_process.append(np.random.choice([4, 5], p=[0.4, 0.6]))
            purchasing_time_patterns.append(np.random.choice(["musiman", "peristiwa khusus", "diskon"], p=[0.2, 0.1, 0.7]))
            communication_channel.append(np.random.choice(["social media", "phone"], p=[0.6, 0.4]))
            complaints.append(np.random.choice(["positif", "netral"], p=[0.7, 0.3]))
            communication_quality.append(np.random.choice(["bagus", "sedang"], p=[0.7, 0.3]))
            possibility_of_purchasing_the_same_training.append(np.random.randint(65, 70))
            frequency_engagement.append(8)
            brand_sustainability.append(4)
            rating_training.append(np.random.choice([4, 5], p=[0.7, 0.3]))
            tren_mode_factor.append(np.random.choice(["Ya", "Tidak"], p=[0.8, 0.2]))
            interest_in_discount_program.append(4)
        else:
            cross_selling.append(np.random.choice([data_office[4], data_office[2]], p=[0.1, 0.9]))
            upselling.append(np.random.choice([data_office[-1], data_office[5]], p=[0.1, 0.9]))
            diskon.append(np.random.choice([25, 30], p=[0.9, 0.1]))
            group.append("Group")
            number_of_participants.append(np.random.randint(10, 13))
            training_total_meetings.append(np.random.choice([11, 12], p=[0.9, 0.1]))
            harga = dictt[office[i]] - (dictt[office[i]]*(diskon[-1]/100)) - (300000*(12-training_total_meetings[-1]))
            satisfaction.append(np.random.choice([4, 5], p=[0.6, 0.4]))
            level_training_process.append(np.random.choice([4, 5], p=[0.6, 0.4]))
            purchasing_time_patterns.append(np.random.choice(["musiman", "peristiwa khusus", "diskon"], p=[0.2, 0.2, 0.6]))
            communication_channel.append(np.random.choice(["social media", "phone"], p=[0.4, 0.6]))
            complaints.append(np.random.choice(["positif", "netral"], p=[0.6, 0.4]))
            communication_quality.append(np.random.choice(["bagus", "sedang"], p=[0.6, 0.4]))
            possibility_of_purchasing_the_same_training.append(np.random.randint(60, 70))
            frequency_engagement.append(7)
            brand_sustainability.append(5)
            rating_training.append(np.random.choice([4, 5], p=[0.9, 0.1]))
            tren_mode_factor.append(np.random.choice(["Ya", "Tidak"], p=[0.8, 0.2]))
            interest_in_discount_program.append(4)
    elif office[i] == data_office[6]:
        if i <= 4061:
            cross_selling.append(np.random.choice([data_office[3], data_office[1]], p=[0.9, 0.1]))
            upselling.append(np.random.choice([data_office[6], data_office[3]], p=[0.9, 0.1]))
            diskon.append(3)
            group.append("Retail")
            number_of_participants.append(np.random.randint(4, 6))
            training_total_meetings.append(np.random.choice([7, 8], p=[0.1, 0.9]))
            harga = dictt[office[i]] - (dictt[office[i]]*(diskon[-1]/100)) - (50000*(8-training_total_meetings[-1]))
            satisfaction.append(np.random.choice([1, 2], p=[0.4, 0.6]))
            level_training_process.append(np.random.choice([1, 2], p=[0.4, 0.6]))
            purchasing_time_patterns.append(np.random.choice(["bulan", "hari spesifik"], p=[0.4, 0.6]))
            communication_channel.append(np.random.choice(["email", "phone"], p=[0.2, 0.8]))
            complaints.append(np.random.choice(["negatif", "netral"], p=[0.4, 0.6]))
            communication_quality.append(np.random.choice(["buruk", "sedang"], p=[0.6, 0.4]))
            possibility_of_purchasing_the_same_training.append(np.random.randint(30, 41))
            frequency_engagement.append(3)
            brand_sustainability.append(np.random.choice([9, 10], p=[0.2, 0.8]))
            rating_training.append(np.random.choice([1, 2], p=[0.2, 0.8]))
            tren_mode_factor.append("Tidak")
            interest_in_discount_program.append(2)
        else:
            cross_selling.append(np.random.choice([data_office[3], data_office[1]], p=[0.1, 0.9]))
            upselling.append(np.random.choice([data_office[6], data_office[3]], p=[0.1, 0.9]))
            diskon.append(2)
            group.append("Retail")
            number_of_participants.append(np.random.randint(4, 6))
            training_total_meetings.append(np.random.choice([7, 8], p=[0.9, 0.1]))
            harga = dictt[office[i]] - (dictt[office[i]]*(diskon[-1]/100)) - (50000*(8-training_total_meetings[-1]))
            satisfaction.append(np.random.choice([1, 2], p=[0.6, 0.4]))
            level_training_process.append(np.random.choice([1, 2], p=[0.6, 0.4]))
            purchasing_time_patterns.append(np.random.choice(["bulan", "hari spesifik"], p=[0.6, 0.4]))
            communication_channel.append(np.random.choice(["email", "phone"], p=[0.7, 0.3]))
            complaints.append(np.random.choice(["negatif", "netral"], p=[0.6, 0.4]))
            communication_quality.append(np.random.choice(["buruk", "sedang"], p=[0.4, 0.6]))
            possibility_of_purchasing_the_same_training.append(np.random.randint(20, 30))
            frequency_engagement.append(2)
            brand_sustainability.append(np.random.choice([9, 10], p=[0.9, 0.1]))
            rating_training.append(np.random.choice([1, 2], p=[0.8, 0.2]))
            tren_mode_factor.append("Tidak")
            interest_in_discount_program.append(2)
    else:
        if i <= 4685:
            cross_selling.append(np.random.choice([data_office[4], data_office[3]], p=[0.9, 0.1]))
            upselling.append(np.random.choice([data_office[4], data_office[-1]], p=[0.9, 0.1]))
            diskon.append(np.random.choice([10, 15], p=[0.2, 0.8]))
            group.append(np.random.choice(["Group", "Retail"], p=[0.8, 0.2]))
            number_of_participants.append(np.random.randint(9, 11))
            training_total_meetings.append(9)
            harga = dictt[office[i]] - (dictt[office[i]]*(diskon[-1]/100)) - (100000*(9-training_total_meetings[-1]))
            satisfaction.append(np.random.choice([3, 4], p=[0.7, 0.3]))
            level_training_process.append(np.random.choice([4, 3], p=[0.3, 0.7]))
            purchasing_time_patterns.append(np.random.choice(["bulan", "hari spesifik", "diskon"], p=[0.2, 0.2, 0.6]))
            communication_channel.append(np.random.choice(["social media", "phone"], p=[0.6, 0.4]))
            complaints.append(np.random.choice(["positif", "netral", "negatif"], p=[0.3, 0.6, 0.1]))
            communication_quality.append(np.random.choice(["bagus", "sedang", "buruk"], p=[0.4, 0.5, 0.1]))
            possibility_of_purchasing_the_same_training.append(np.random.randint(45, 51))
            frequency_engagement.append(6)
            brand_sustainability.append(5)
            rating_training.append(np.random.choice([3, 4], p=[0.8, 0.2]))
            tren_mode_factor.append(np.random.choice(["Ya", "Tidak"], p=[0.8, 0.2]))
            interest_in_discount_program.append(3)
        else:
            cross_selling.append(np.random.choice([data_office[4], data_office[3]], p=[0.1, 0.9]))
            upselling.append(np.random.choice([data_office[4], data_office[-1]], p=[0.1, 0.9]))
            diskon.append(np.random.choice([10, 15], p=[0.8, 0.2]))
            group.append(np.random.choice(["Group", "Retail"], p=[0.6, 0.4]))
            number_of_participants.append(np.random.randint(6, 8))
            training_total_meetings.append(9)
            harga = dictt[office[i]] - (dictt[office[i]]*(diskon[-1]/100)) - (100000*(9-training_total_meetings[-1]))
            satisfaction.append(np.random.choice([3, 4], p=[0.9, 0.1]))
            level_training_process.append(np.random.choice([4, 3], p=[0.1, 0.9]))
            purchasing_time_patterns.append(np.random.choice(["bulan", "hari spesifik", "diskon"], p=[0.2, 0.2, 0.6]))
            communication_channel.append(np.random.choice(["social media", "phone"], p=[0.6, 0.4]))
            complaints.append(np.random.choice(["positif", "netral", "negatif"], p=[0.1, 0.8, 0.1]))
            communication_quality.append(np.random.choice(["bagus", "sedang", "buruk"], p=[0.2, 0.7, 0.1]))
            possibility_of_purchasing_the_same_training.append(np.random.randint(40, 45))
            frequency_engagement.append(5)
            brand_sustainability.append(6)
            rating_training.append(np.random.choice([3, 4], p=[0.9, 0.1]))
            tren_mode_factor.append(np.random.choice(["Ya", "Tidak"], p=[0.8, 0.2]))
            interest_in_discount_program.append(3)
    
    training_price.append(harga)
    total_payment.append(harga * number_of_participants[-1])

# %%
df["satisfaction_level"] = satisfaction
df["discount_training"] = diskon
df["group"] = group
df["level_training_process"] = level_training_process
df["purchasing_time_patterns"] = purchasing_time_patterns
df["communication_channel"] = communication_channel
df["complaints"] = complaints
df["communication_quality"] = communication_quality
df["possibility_of_purchasing_the_same_training"] = possibility_of_purchasing_the_same_training
df["frequency_engagement"] = frequency_engagement
df["brand_sustainability"] = brand_sustainability

df["tren_mode_factor"] = tren_mode_factor
df["interest_in_discount_program"] = interest_in_discount_program
df["total_payment"] = total_payment
df["training_session"] = training_total_meetings
df["number_of_participant"] = number_of_participants
df["training_price"] = training_price
df["training_field"] = "Office & Administration Series"
df["training_name"] = office
df["cross_selling"] = cross_selling
df["upselling"] = upselling
df.head()
# Out:
#   company_ID          company_name              company_pic  \
# 0      P0001   Tribakti Inspektama         Lasmanto Pratiwi
# 1      P0002  Bank Bukopin Syariah     Puti Gina Napitupulu
# 2      P0003  Bank Bukopin Syariah  Karna Purwanti, S.I.Kom
# 3      P0004      Kementrian Agama            Tania Yolanda
# 4      P0005                 M3kom        Zaenab Anggriawan
#
#                                      company_address        company_phone  \
# 0  Jalan Cihampelas No. 282\nPontianak, Kalimanta...   +62 (183) 655 1415
# 1    Jalan Tubagus Ismail No. 02\nSukabumi, BB 74318       (097) 773 7113
# 2    Gg. Pelajar Pejuang No. 660\nJambi, Jambi 60449  +62 (0801) 007-5669
# 3               Jl. Cihampelas No. 8\nTual, ST 59647    +62-0247-253-2150
# 4    Gang Moch. Ramdan No. 083\nPayakumbuh, SS 13214       (025) 406 2520
#
#                   company_email  \
# 0  muhammadnasyidah@example.org
# 1     januarkamaria@example.net
# 2         rprasetyo@example.net
# ...

# %%
df.to_csv("./dataset/Office & Administration Series.csv")
